# %% [markdown]
# # Prepare: authenticate with tranSMART
#
# Authenticate with tranSMART first if you want to execute any of the analysis in the boxes below again.
#
# **Step 1**: Please open URL http://localhost:8080/transmart/oauth/authorize?response_type=code&client_id=api-client&client_secret=api-client&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2Ftransmart%2Foauth%2Fverify
#
# **Step 2**: paste token in the token parameter below.

# %%
require("transmartRClient")
connectToTransmart("http://localhost:8080/transmart", prefetched.request.token = "4xIZYZ")
# Out:
# Loading required package: transmartRClient
# Loading required package: RCurl
# Loading required package: bitops
# Loading required package: RJSONIO
# Loading required package: plyr
# Loading required package: RProtoBuf
#
# Attaching package: ‘RProtoBuf’
#
# The following object is masked from ‘package:RCurl’:
#
#     clone
#
# Loading required package: hash
# hash-2.2.6 provided by Decision Patterns
#
#
# Attaching package: ‘hash’
#
# The following object is masked from ‘package:RProtoBuf’:
#
#     clear
#
# Loading required package: reshape
#
# Attaching package: ‘reshape’
#
# The following objects are masked from ‘package:plyr’:
#
#     rename, round_any
# Authentication completed.
# Connection successful.

# %% [markdown]
# If the output above is: Authentication completed. TRUE ,
# then you can continue below.

# %% [markdown]
# # Get studies and observations data

# %%
# Get studies
studies <- getStudies()
studies
# Out:
#              id api.link.self.href       ontologyTerm.fullName
# GSE8581 GSE8581   /studies/gse8581 \\Public Studies\\GSE8581\\

# %%
study <- "GSE8581"  

# Retrieve Clinical Data
allObservations <- getObservations(study, as.data.frame = T)
# show first 3 rows, just to get impression of the fields available
allObservations$observations[1:3,]
# Out:
#   subject.id Biomarker Data_GPL570                    Endpoints_Diagnosis
# 1 1000384597                  <NA>          non-small cell adenocarcinoma
# 2 1000384598                     E non-small cell squamous cell carcinoma
# 3 1000384599                     E                           inflammation
#   Endpoints_FEV1 Endpoints_Forced Expiratory Volume Ratio Subjects_Age
# 1           1.41                                       51           65
# 2           1.29                                       53           77
# 3           4.04                                       79           55
#   Subjects_Height (inch)                 Subjects_Lung Disease
# 1                     66 chronic obstructive pulmonary disease
# 2                     67 chronic obstructive pulmonary disease
# 3                     69                               control
#   Subjects_Organism Subjects_Race Subjects_Sex
# 1      Homo sapiens Afro American       female
# 2      Homo sapiens     Caucasian       female
# 3      Homo sapiens     Caucasian         male

# %% [markdown]
# # Making subsets based on attributes (aka "concepts")

# %%
# get the concepts for this study
concepts <- getConcepts(study)
concepts
# Out:
#                                        name
# 1                             Afro American
# 2                                       Age
# 3                            Biomarker Data
# 4                                 carcinoid
# 5                                 Caucasian
# 6     chronic obstructive pulmonary disease
# 7                                   control
# 8                                 Diagnosis
# 9                                 emphysema
# 10                                Endpoints
# 11                                   female
# 12                                     FEV1
# 13           Forced Expiratory Volume Ratio
# 14                             giant bullae
# 15                         Giant Cell Tumor
# 16                                   GPL570
# 17                            Height (inch)
# 18                                 hematoma
# 19                             Homo sapiens
# 20                             inflammation
# 21                                     Lung
# 22                             Lung Disease
# 23                                 lymphoma
# 24                                     male
# 25 metastatic non-small cell adenocarcinoma
# 26          metastatic renal cell carcinoma
# 27                            no malignancy
# 28            non-small cell adenocarcinoma
# 29   non-small cell squamous cell carcinoma
# 30                            not specified
# 31                                NSC-Mixed
# 32                                 Organism
# 33                                     Race
# 34                                      Sex
# 35                                 Subjects
# 36                                  Unknown
#                                                                                       fullName
# 1                                   \\Public Studies\\GSE8581\\Subjects\\Race\\Afro American\\
# 2                                                   \\Public Studies\\GSE8581\\Subjects\\Age\\
# 3                                                  \\Public Studies\\GSE8581\\Biomarker Data\\
# 4                                 \\Public Studies\\GSE8581\\Endpoints\\Diagnosis\\carcinoid\\
# 5                                       \\Public Studies\\GSE8581\\Subjects\\Race\\Caucasian\\
# 6   \\Public Studies\\GSE8581\\Subjects\\Lung Disease\\chronic obstructive pulmonary disease\\
# 7                                 \\Public Studies\\GSE8581\\Subjects\\Lung Disease\\control\\
# 8                                            \\Public Studies\\GSE8581\\Endpoints\\Diagnosis\\
# 9                                 \\Public Studies\\GSE8581\\Endpoints\\Diagnosis\\emphysema\\
# 10                                                      \\Public Studies\\GSE8581\\Endpoints\\
# 11                                          \\Public Studies\\GSE8581\\Subjects\\Sex\\female\\
# 12                                                \\Public Studies\\GSE8581\\Endpoints\\FEV1\\
# 13                      \\Public Studies\\GSE8581\\Endpoints\\Forced Expiratory Volume Ratio\\
# 14                             \\Public Studies\\GSE8581\\Endpoints\\Diagnosis\\giant bullae\\
# 15                         \\Public Studies\\GSE8581\\Endpoints\\Diagnosis\\Giant Cell Tumor\\
# 16                                         \\Public Studies\\GSE8581\\Biomarker Data\\GPL570\\
# 17                                        \\Public Studies\\GSE8581\\Subjects\\Height (inch)\\
# 18                                 \\Public Studies\\GSE8581\\Endpoints\\Diagnosis\\hematoma\\
# 19                               \\Public Studies\\GSE8581\\Subjects\\Organism\\Homo sapiens\\
# 20                             \\Public Studies\\GSE8581\\Endpoints\\Diagnosis\\inflammation\\
# 21                                   \\Public Studies\\GSE8581\\Biomarker Data\\GPL570\\Lung\\
# 22                                         \\Public Studies\\GSE8581\\Subjects\\Lung Disease\\
# 23                                 \\Public Studies\\GSE8581\\Endpoints\\Diagnosis\\lymphoma\\
# 24                                            \\Public Studies\\GSE8581\\Subjects\\Sex\\male\\
# 25 \\Public Studies\\GSE8581\\Endpoints\\Diagnosis\\metastatic non-small cell adenocarcinoma\\
# 26          \\Public Studies\\GSE8581\\Endpoints\\Diagnosis\\metastatic renal cell carcinoma\\
# 27                            \\Public Studies\\GSE8581\\Endpoints\\Diagnosis\\no malignancy\\
# 28            \\Public Studies\\GSE8581\\Endpoints\\Diagnosis\\non-small cell adenocarcinoma\\
# 29   \\Public Studies\\GSE8581\\Endpoints\\Diagnosis\\non-small cell squamous cell carcinoma\\
# 30                          \\Public Studies\\GSE8581\\Subjects\\Lung Disease\\not specified\\
# 31                                \\Public Studies\\GSE8581\\Endpoints\\Diagnosis\\NSC-Mixed\\
# 32                                             \\Public Studies\\GSE8581\\Subjects\\Organism\\
# 33                                                 \\Public Studies\\GSE8581\\Subjects\\Race\\
# 34                                                  \\Public Studies\\GSE8581\\Subjects\\Sex\\
# 35                                                       \\Public Studies\\GSE8581\\Subjects\\
# 36                                  \\Public Studies\\GSE8581\\Endpoints\\Diagnosis\\Unknown\\
#                  type
# 1  CATEGORICAL_OPTION
# 2             NUMERIC
# 3             UNKNOWN
# 4  CATEGORICAL_OPTION
# 5  CATEGORICAL_OPTION
# 6  CATEGORICAL_OPTION
# 7  CATEGORICAL_OPTION
# 8             UNKNOWN
# 9  CATEGORICAL_OPTION
# 10            UNKNOWN
# 11 CATEGORICAL_OPTION
# 12            NUMERIC
# 13            NUMERIC
# 14 CATEGORICAL_OPTION
# 15 CATEGORICAL_OPTION
# 16            UNKNOWN
# 17            NUMERIC
# 18 CATEGORICAL_OPTION
# 19 CATEGORICAL_OPTION
# 20 CATEGORICAL_OPTION
# 21   HIGH_DIMENSIONAL
# 22            UNKNOWN
# 23 CATEGORICAL_OPTION
# 24 CATEGORICAL_OPTION
# 25 CATEGORICAL_OPTION
# 26 CATEGORICAL_OPTION
# 27 CATEGORICAL_OPTION
# 28 CATEGORICAL_OPTION
# 29 CATEGORICAL_OPTION
# 30 CATEGORICAL_OPTION
# 31 CATEGORICAL_OPTION
# 32            UNKNOWN
# 33            UNKNOWN
# 34            UNKNOWN
# 35            UNKNOWN
# 36 CATEGORICAL_OPTION
#                                                                               api.link.self.href
# 1                                        /studies/gse8581/concepts/Subjects/Race/Afro%20American
# 2                                                         /studies/gse8581/concepts/Subjects/Age
# 3                                                     /studies/gse8581/concepts/Biomarker%20Data
# 4                                        /studies/gse8581/concepts/Endpoints/Diagnosis/carcinoid
# 5                                              /studies/gse8581/concepts/Subjects/Race/Caucasian
# 6  /studies/gse8581/concepts/Subjects/Lung%20Disease/chronic%20obstructive%20pulmonary%20disease
# 7                                      /studies/gse8581/concepts/Subjects/Lung%20Disease/control
# 8                                                  /studies/gse8581/concepts/Endpoints/Diagnosis
# 9                                        /studies/gse8581/concepts/Endpoints/Diagnosis/emphysema
# 10                                                           /studies/gse8581/concepts/Endpoints
# 11                                                 /studies/gse8581/concepts/Subjects/Sex/female
# 12                                                      /studies/gse8581/concepts/Endpoints/FEV1
# 13                      /studies/gse8581/concepts/Endpoints/Forced%20Expiratory%20Volume%20Ratio
# 14                                  /studies/gse8581/concepts/Endpoints/Diagnosis/giant%20bullae
# 15                            /studies/gse8581/concepts/Endpoints/Diagnosis/Giant%20Cell%20Tumor
# 16                                             /studies/gse8581/concepts/Biomarker%20Data/GPL570
# 17                                        /studies/gse8581/concepts/Subjects/Height%20%28inch%29
# 18                                        /studies/gse8581/concepts/Endpoints/Diagnosis/hematoma
# 19                                    /studies/gse8581/concepts/Subjects/Organism/Homo%20sapiens
# 20                                    /studies/gse8581/concepts/Endpoints/Diagnosis/inflammation
# 21                                        /studies/gse8581/concepts/Biomarker%20Data/GPL570/Lung
# 22                                             /studies/gse8581/concepts/Subjects/Lung%20Disease
# 23                                        /studies/gse8581/concepts/Endpoints/Diagnosis/lymphoma
# 24                                                   /studies/gse8581/concepts/Subjects/Sex/male
# 25  /studies/gse8581/concepts/Endpoints/Diagnosis/metastatic%20non-small%20cell%20adenocarcinoma
# 26           /studies/gse8581/concepts/Endpoints/Diagnosis/metastatic%20renal%20cell%20carcinoma
# 27                                 /studies/gse8581/concepts/Endpoints/Diagnosis/no%20malignancy
# 28               /studies/gse8581/concepts/Endpoints/Diagnosis/non-small%20cell%20adenocarcinoma
# 29  /studies/gse8581/concepts/Endpoints/Diagnosis/non-small%20cell%20squamous%20cell%20carcinoma
# 30                             /studies/gse8581/concepts/Subjects/Lung%20Disease/not%20specified
# 31                                       /studies/gse8581/concepts/Endpoints/Diagnosis/NSC-Mixed
# 32                                                   /studies/gse8581/concepts/Subjects/Organism
# 33                                                       /studies/gse8581/concepts/Subjects/Race
# 34                                                        /studies/gse8581/concepts/Subjects/Sex
# 35                                                            /studies/gse8581/concepts/Subjects
# 36                                         /studies/gse8581/concepts/Endpoints/Diagnosis/Unknown
#                                                                                    api.link.observations.href
# 1                                        /studies/gse8581/concepts/Subjects/Race/Afro%20American/observations
# 2                                                         /studies/gse8581/concepts/Subjects/Age/observations
# 3                                                     /studies/gse8581/concepts/Biomarker%20Data/observations
# 4                                        /studies/gse8581/concepts/Endpoints/Diagnosis/carcinoid/observations
# 5                                              /studies/gse8581/concepts/Subjects/Race/Caucasian/observations
# 6  /studies/gse8581/concepts/Subjects/Lung%20Disease/chronic%20obstructive%20pulmonary%20disease/observations
# 7                                      /studies/gse8581/concepts/Subjects/Lung%20Disease/control/observations
# 8                                                  /studies/gse8581/concepts/Endpoints/Diagnosis/observations
# 9                                        /studies/gse8581/concepts/Endpoints/Diagnosis/emphysema/observations
# 10                                                           /studies/gse8581/concepts/Endpoints/observations
# 11                                                 /studies/gse8581/concepts/Subjects/Sex/female/observations
# 12                                                      /studies/gse8581/concepts/Endpoints/FEV1/observations
# 13                      /studies/gse8581/concepts/Endpoints/Forced%20Expiratory%20Volume%20Ratio/observations
# 14                                  /studies/gse8581/concepts/Endpoints/Diagnosis/giant%20bullae/observations
# 15                            /studies/gse8581/concepts/Endpoints/Diagnosis/Giant%20Cell%20Tumor/observations
# 16                                             /studies/gse8581/concepts/Biomarker%20Data/GPL570/observations
# 17                                        /studies/gse8581/concepts/Subjects/Height%20%28inch%29/observations
# 18                                        /studies/gse8581/concepts/Endpoints/Diagnosis/hematoma/observations
# 19                                    /studies/gse8581/concepts/Subjects/Organism/Homo%20sapiens/observations
# 20                                    /studies/gse8581/concepts/Endpoints/Diagnosis/inflammation/observations
# 21                                                                                                       <NA>
# 22                                             /studies/gse8581/concepts/Subjects/Lung%20Disease/observations
# 23                                        /studies/gse8581/concepts/Endpoints/Diagnosis/lymphoma/observations
# 24                                                   /studies/gse8581/concepts/Subjects/Sex/male/observations
# 25  /studies/gse8581/concepts/Endpoints/Diagnosis/metastatic%20non-small%20cell%20adenocarcinoma/observations
# 26           /studies/gse8581/concepts/Endpoints/Diagnosis/metastatic%20renal%20cell%20carcinoma/observations
# 27                                 /studies/gse8581/concepts/Endpoints/Diagnosis/no%20malignancy/observations
# 28               /studies/gse8581/concepts/Endpoints/Diagnosis/non-small%20cell%20adenocarcinoma/observations
# 29  /studies/gse8581/concepts/Endpoints/Diagnosis/non-small%20cell%20squamous%20cell%20carcinoma/observations
# 30                             /studies/gse8581/concepts/Subjects/Lung%20Disease/not%20specified/observations
# 31                                       /studies/gse8581/concepts/Endpoints/Diagnosis/NSC-Mixed/observations
# 32                                                   /studies/gse8581/concepts/Subjects/Organism/observations
# 33                                                       /studies/gse8581/concepts/Subjects/Race/observations
# 34                                                        /studies/gse8581/concepts/Subjects/Sex/observations
# 35                                                            /studies/gse8581/concepts/Subjects/observations
# 36                                         /studies/gse8581/concepts/Endpoints/Diagnosis/Unknown/observations
#                                 api.link.parent.href
# 1            /studies/gse8581/concepts/Subjects/Race
# 2                 /studies/gse8581/concepts/Subjects
# 3                     /studies/gse8581/concepts/ROOT
# 4      /studies/gse8581/concepts/Endpoints/Diagnosis
# 5            /studies/gse8581/concepts/Subjects/Race
# 6  /studies/gse8581/concepts/Subjects/Lung%20Disease
# 7  /studies/gse8581/concepts/Subjects/Lung%20Disease
# 8                /studies/gse8581/concepts/Endpoints
# 9      /studies/gse8581/concepts/Endpoints/Diagnosis
# 10                    /studies/gse8581/concepts/ROOT
# 11            /studies/gse8581/concepts/Subjects/Sex
# 12               /studies/gse8581/concepts/Endpoints
# 13               /studies/gse8581/concepts/Endpoints
# 14     /studies/gse8581/concepts/Endpoints/Diagnosis
# 15     /studies/gse8581/concepts/Endpoints/Diagnosis
# 16        /studies/gse8581/concepts/Biomarker%20Data
# 17                /studies/gse8581/concepts/Subjects
# 18     /studies/gse8581/concepts/Endpoints/Diagnosis
# 19       /studies/gse8581/concepts/Subjects/Organism
# 20     /studies/gse8581/concepts/Endpoints/Diagnosis
# 21 /studies/gse8581/concepts/Biomarker%20Data/GPL570
# 22                /studies/gse8581/concepts/Subjects
# 23     /studies/gse8581/concepts/Endpoints/Diagnosis
# 24            /studies/gse8581/concepts/Subjects/Sex
# 25     /studies/gse8581/concepts/Endpoints/Diagnosis
# 26     /studies/gse8581/concepts/Endpoints/Diagnosis
# 27     /studies/gse8581/concepts/Endpoints/Diagnosis
# 28     /studies/gse8581/concepts/Endpoints/Diagnosis
# 29     /studies/gse8581/concepts/Endpoints/Diagnosis
# 30 /studies/gse8581/concepts/Subjects/Lung%20Disease
# 31     /studies/gse8581/concepts/Endpoints/Diagnosis
# 32                /studies/gse8581/concepts/Subjects
# 33                /studies/gse8581/concepts/Subjects
# 34                /studies/gse8581/concepts/Subjects
# 35                    /studies/gse8581/concepts/ROOT
# 36     /studies/gse8581/concepts/Endpoints/Diagnosis
#                                                   api.link.children.NA.href
# 1                                                                      <NA>
# 2                                                                      <NA>
# 3                         /studies/gse8581/concepts/Biomarker%20Data/GPL570
# 4                                                                      <NA>
# 5                                                                      <NA>
# 6                                                                      <NA>
# 7                                                                      <NA>
# 8                     /studies/gse8581/concepts/Endpoints/Diagnosis/Unknown
# 9                                                                      <NA>
# 10 /studies/gse8581/concepts/Endpoints/Forced%20Expiratory%20Volume%20Ratio
# 11                                                                     <NA>
# 12                                                                     <NA>
# 13                                                                     <NA>
# 14                                                                     <NA>
# 15                                                                     <NA>
# 16                   /studies/gse8581/concepts/Biomarker%20Data/GPL570/Lung
# 17                                                                     <NA>
# 18                                                                     <NA>
# 19                                                                     <NA>
# 20                                                                     <NA>
# 21                                                                     <NA>
# 22        /studies/gse8581/concepts/Subjects/Lung%20Disease/not%20specified
# 23                                                                     <NA>
# 24                                                                     <NA>
# 25                                                                     <NA>
# 26                                                                     <NA>
# 27                                                                     <NA>
# 28                                                                     <NA>
# 29                                                                     <NA>
# 30                                                                     <NA>
# 31                                                                     <NA>
# 32               /studies/gse8581/concepts/Subjects/Organism/Homo%20sapiens
# 33                        /studies/gse8581/concepts/Subjects/Race/Caucasian
# 34                              /studies/gse8581/concepts/Subjects/Sex/male
# 35                                   /studies/gse8581/concepts/Subjects/Sex
# 36                                                                     <NA>
#        api.link.children.NA.title
# 1                            <NA>
# 2                            <NA>
# 3                          GPL570
# 4                            <NA>
# 5                            <NA>
# 6                            <NA>
# 7                            <NA>
# 8                         Unknown
# 9                            <NA>
# 10 Forced Expiratory Volume Ratio
# 11                           <NA>
# 12                           <NA>
# 13                           <NA>
# 14                           <NA>
# 15                           <NA>
# 16                           Lung
# 17                           <NA>
# 18                           <NA>
# 19                           <NA>
# 20                           <NA>
# 21                           <NA>
# 22                  not specified
# 23                           <NA>
# 24                           <NA>
# 25                           <NA>
# 26                           <NA>
# 27                           <NA>
# 28                           <NA>
# 29                           <NA>
# 30                           <NA>
# 31                           <NA>
# 32                   Homo sapiens
# 33                      Caucasian
# 34                           male
# 35                            Sex
# 36                           <NA>
#                                             api.link.highdim.href
# 1                                                            <NA>
# 2                                                            <NA>
# 3                                                            <NA>
# 4                                                            <NA>
# 5                                                            <NA>
# 6                                                            <NA>
# 7                                                            <NA>
# 8                                                            <NA>
# 9                                                            <NA>
# 10                                                           <NA>
# 11                                                           <NA>
# 12                                                           <NA>
# 13                                                           <NA>
# 14                                                           <NA>
# 15                                                           <NA>
# 16                                                           <NA>
# 17                                                           <NA>
# 18                                                           <NA>
# 19                                                           <NA>
# 20                                                           <NA>
# 21 /studies/gse8581/concepts/Biomarker%20Data/GPL570/Lung/highdim
# 22                                                           <NA>
# 23                                                           <NA>
# 24                                                           <NA>
# 25                                                           <NA>
# 26                                                           <NA>
# 27                                                           <NA>
# 28                                                           <NA>
# 29                                                           <NA>
# 30                                                           <NA>
# 31                                                           <NA>
# 32                                                           <NA>
# 33                                                           <NA>
# 34                                                           <NA>
# 35                                                           <NA>
# 36                                                           <NA>

# %%
observations <- getObservations(study, 
                                # concept names from api.link.self.href column above: 
                                concept.links =
                                  c("/studies/gse8581/concepts/Subjects/Age",
                                    "/studies/gse8581/concepts/Subjects/Sex")
                                )
# make two groups based on gender :
observations_female <- subset(observations$observations, Sex == 'female')
observations_male <- subset(observations$observations, Sex == 'male')
# show age distribution:
d <- density(as.integer(observations_male$Age)) # returns the density data 
plot(d, col="blue", main="Male vs Female groups age distribution") # plots the results
legend("topright", c("Males","Females"), pch = 1, col=c("blue", "red"))
d <- density(as.integer(observations_female$Age)) # returns the density data 
lines(d, col="red") # plots the results
# Out:
# Plot with title “Male vs Female groups age distribution”

# %% [markdown]
# # Exercise 1
#
# Make a distribution plot similar to the plot above, but now comparing the ages of "control" vs "chronic obstructive pulmonary disease"  (if you did the previous RStudio exercise, you can just paste your code in a code cell below).
#
# NB: run also all necessary cells above to fetch the data that your script requires.

# %%
# Out:
# [1] 1

# %% [markdown]
# # Downloading the expression data
# This can take a while (~1 minute)

# %%
dataDownloaded <- getHighdimData(study.name = study, concept.match = "Lung", projection = "log_intensity")
# Out:
# Retrieving data from server. This can take some time, depending on your network connection speed. 2015-10-13 05:36:26
# Retrieving data:
#  24.363 MiB downloaded.
# Download complete.
# Received data for 55 assays. Unpacking data. 2015-10-13 05:37:54
#   |======================================================================| 100%
# Data unpacked. Converting to data.frame. 2015-10-13 05:38:16
# Additional biomarker information is available.
# This function will return a list containing a dataframe containing the high dimensional data and a hash describing which (column) labels refer to which bioMarker

# %%
summary(dataDownloaded)
# Out:
#                     Length Class      Mode
# data                54680  data.frame list
# labelToBioMarkerMap 54674  hash       S4

# %%
# preview part of the data
data<-dataDownloaded[["data"]]
data[1:10,1:10]
# Out:
#    assayId        patientId sampleTypeName timepointName tissueTypeName
# 1    45741 GSE8581GSM213034          Human                         Lung
# 2    45742 GSE8581GSM212811          Human                         Lung
# 3    45743 GSE8581GSM213036          Human                         Lung
# 4    45744 GSE8581GSM212075          Human                         Lung
# 5    45745 GSE8581GSM211008          Human                         Lung
# 6    45746 GSE8581GSM210090          Human                         Lung
# 7    45747 GSE8581GSM212855          Human                         Lung
# 8    45748 GSE8581GSM212070          Human                         Lung
# 9    45749 GSE8581GSM212810          Human                         Lung
# 10   45750 GSE8581GSM210193          Human                         Lung
#    platform X235956_at X226260_x_at X232632_at X214503_x_at
# 1    GPL570   6.461792     4.969012  5.5469747    0.3130368
# 2    GPL570   7.461758     1.053695  5.5075473   -1.1142164
# 3    GPL570   6.907191     5.064348  7.6373856    0.5699965
# 4    GPL570   7.775558     4.766791  6.5959168   -0.1566947
# 5    GPL570   7.308785     3.559235  8.2498530    0.2687817
# 6    GPL570   6.286654     4.967538  7.3189856    0.1080092
# 7    GPL570   4.924318     4.085595  4.5525123    1.0878905
# 8    GPL570   8.004900     4.767745  6.7625349    1.1942699
# 9    GPL570   2.411315    -1.447194  0.2749713   -1.3216468
# 10   GPL570   6.670685     4.025853  7.5389339    0.9389105

# %% [markdown]
# # Prepare the data for easy usage in different standard R functions
# The steps below show how the table above is processed into a simple table that contains only expression values + an extra feature of having patient identifiers as row names.

# %%
# select gene expression data, which is the data *excluding* columns 1 to 6:
expression_data<-data[,-c(1:6)]
expression_data[1:3,1:3]
dim(expression_data)
# add patientId as the row name for the expression_data matrix:
rownames(expression_data)<-data$patientId
expression_data[1:3,1:3]
# Out:
#   X235956_at X226260_x_at X232632_at
# 1   6.461792     4.969012   5.546975
# 2   7.461758     1.053695   5.507547
# 3   6.907191     5.064348   7.637386
# [1]    55 54674
#                  X235956_at X226260_x_at X232632_at
# GSE8581GSM213034   6.461792     4.969012   5.546975
# GSE8581GSM212811   7.461758     1.053695   5.507547
# GSE8581GSM213036   6.907191     5.064348   7.637386

# %% [markdown]
# # Heatmap
# If the dimensions of the expression_data table are large, you may want to create a subset of the data first. Here we use a probelist as a *subset* for the probes, based on the list found in: "Bhattacharya S., Srisuma S., Demeo D. L., et al.,  Molecular biomarkers for quantitative and discrete COPD phenotypes.American Journal of Respiratory Cell and Molecular Biology. 2009;40(3):359–367. doi: 10.1165/rcmb.2008-0114OC."

# %%
#Make a heatmap
probeNames<- c("1552622_s_at","1555318_at","1557293_at","1558280_s_at","1558411_at","1558515_at","1559964_at","204284_at","205051_s_at","205528_s_at","208835_s_at","209377_s_at","209815_at","211548_s_at","212179_at","212263_at","213156_at","213269_at","213650_at","213878_at","215359_x_at","215933_s_at","218352_at","218490_s_at","220094_s_at","220906_at","220925_at","222108_at","224711_at","225318_at","225595_at","225835_at","225892_at","226316_at","226492_at","226534_at","226666_at","226800_at","227095_at","227105_at","227148_at","227812_at","227852_at","227930_at","227947_at","228157_at","228630_at","228665_at","228760_at","228850_s_at","228875_at","228963_at","229111_at","229572_at","230142_s_at","230986_at","232014_at","235423_at","235810_at","238712_at","238992_at","239842_x_at","239847_at","241936_x_at","242389_at")
#note: this is because R automatically prepends "X" in front of column names that start with a numerical value. Therefore prepend "X"
probeNames<- paste("X", probeNames, sep = "")

# %%
# select only the cases and controls (excluding the patients for which the lung disease is not specified). Note: in the observation table the database IDs 
# are used to identify the patients and not the patient IDs that are used in the gene expression dataset
cases <- allObservations$observations$subject.id[allObservations$observations$'Subjects_Lung Disease' == "chronic obstructive pulmonary disease"]
controls <- allObservations$observations$subject.id[allObservations$observations$'Subjects_Lung Disease' == "control"]

# %%
# now we have the *internal database* IDs for the patients, but we need to get the patient IDs because 
# this is the index of the expression_data matrix. 
# These can be retrieved from the subjectInfo table: 
subjectInfo <- allObservations$subjectInfo
patientIDsCase    <- subjectInfo$subject.inTrialId[ subjectInfo$subject.id %in% cases ] 
patientIDsControl <- subjectInfo$subject.inTrialId[ subjectInfo$subject.id %in% controls] 

# patient sets containing case and control patientIDs
patientSets <- c(patientIDsCase, patientIDsControl)
patientSets <- patientSets[which(patientSets %in% rownames(expression_data))]
# make a subset of the data based on the selected patientSets and the probelist, and transpose the 
# table so that the rows now contain probe names
subset<-t(expression_data[patientSets,probeNames]) 
# for ease of recognition: append "Case" and "Control" to the patient names
colnames(subset)[colnames(subset)%in% patientIDsCase] <- paste(colnames(subset)[colnames(subset)%in% patientIDsCase],"Case", sep="_" )
colnames(subset)[colnames(subset)%in% patientIDsControl] <- paste( colnames(subset)[colnames(subset)%in% patientIDsControl] , "Control",sep= "_")

# make heatmap
heatmap(as.matrix(subset), scale = "row")

# there is one patient that seems to be an outlier: GSE8581GSM212810_Case.
# remove this outlier and plot heatmap again
subset_without_outlier <- subset[,colnames(subset)!= "GSE8581GSM212810_Case"]
heatmap(as.matrix(subset_without_outlier), scale = "row")
# Out:
# plot without title
# plot without title

# %% [markdown]
# # PCA visualization

# %%
# PCA analysis : 
options(warn=-1)# to turn warnings back on, use : options(warn=0)
subset_t <- t(subset_without_outlier)
prcomp_result <- prcomp(x = subset_t)
result_pca <- prcomp_result$x
#result_pca
rownames_pca_result <- rownames(result_pca)
colors <- c()
for (row in rownames_pca_result){ colors <- c(colors, ifelse(grepl("Case", row), "red", "blue")) }
plot(result_pca[,1], result_pca[,2], col=colors)
legend("topright", c("Case","Control"), pch = 1, col=c("red", "blue"))
#3D
# install.packages("plot3D")
plot3D::scatter3D(result_pca[,1], result_pca[,2], result_pca[,3], col=colors, phi=0, theta=0)
legend("topright", c("Case","Control"), pch = 1, col=c("red", "blue"))
# Out:
# Error in loadNamespace(name): there is no package called ‘plot3D’
# plot without title

# %% [markdown]
# # Exercise 2
#
# Try different phi and theta angles in script above to improve the 3D PCA visualization. Tip: try also 0, 60.
