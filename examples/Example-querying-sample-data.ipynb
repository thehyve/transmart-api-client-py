# %% [markdown]
# # Example TranSMART API calls for querying sample data
#
# This notebook demonstrates the querying features of the transmart package, using an example study that contains patient-level and sample-level data.
#
# The example study is loaded into https://glowingbear.thehyve.net as the `CSR` study.
# The source files are available at https://github.com/thehyve/pmc-conversion/tree/master/test_data/test_logic.

# %% [markdown]
# ## Preparation: loading libraries and connect
#
# Follow these first steps to setup dependencies and the connection.
#
# ### Install dependencies
#
# The `transmart` package requires Python 3.x.
#
# ```
# # Install the transmart package and it's dependencies
# pip install transmart[full]
# ```
#
# ### Import packages

# %%
import json
import copy
import requests
from getpass import getpass

# python API client
import transmart
from transmart.api.v2.api import Query
from transmart.api.v2.constraints import atomic
print('transmart python client version: {}'.format(transmart.__version__))
# Out:
# transmart python client version: 0.2.6

# %% [markdown]
# ### Configuration

# %%
# Demo environment settings

keycloak_url = 'https://keycloak-dwh-test.thehyve.net'
transmart_url = 'https://transmart.thehyve.net'
keycloak_realm = 'transmart'
keycloak_client_id = 'transmart-client'

# %% [markdown]
# ### Retrieve offline token for API access
#
# You need to provide your user credentials for https://glowingbear.thehyve.net.
# If you do not have an account yet, please visit the website to register.

# %%
# User credentials
user = getpass(prompt='username: ')
password = getpass(prompt='password: ')
# Out:
# username: ········
# password: ········

# %%
# Fetch offline token for API access
r = requests.post(url=f'{keycloak_url}/auth/realms/{keycloak_realm}/protocol/openid-connect/token',
                  data=dict(grant_type='password',
                            client_id=keycloak_client_id,
                            scope= 'offline_access',
                            username=user,
                            password=password
                           )
                 )
if r.status_code != 200:
    print(r.json())
    raise Exception(f'Error: {r.status_code}')
offline_token = r.json().get('refresh_token')
print('Offline token retrieved successfully')
# Out:
# Offline token retrieved successfully

# %% [markdown]
# ### Connect to the API server

# %%
# Create an API object to perform API queries with, using our user credentials

api = transmart.get_api(
    host=transmart_url,
    kc_url=keycloak_url,
    kc_realm=keycloak_realm,
    client_id=keycloak_client_id,
    offline_token=offline_token,
    print_urls=True)

# Common errors:
# * '401 Client Error: Unauthorized' - Wrong username/password
# * 'HTTPSConnectionPool' - Wrong tranSMART or Keycloak URL or no internet
# * '404 Client Error: Not Found' - Wrong Keycloak realm
# Out:
# https://transmart.thehyve.net/v2/studies
# https://transmart.thehyve.net/v2/tree_nodes?depth=0&counts=False&tags=True
# Existing index cache found. Loaded 10295 tree nodes. Hooray!
# https://transmart.thehyve.net/v2/pedigree/relation_types

# %% [markdown]
# ## Querying the data

# %% [markdown]
# ### Explore available studies and tree structure

# %% [markdown]
# #### Get list of available studies

# %%
studies = api.get_studies().dataframe
studies
# Out:
# https://transmart.thehyve.net/v2/studies
#   bioExperimentId                                         dimensions  id  \
# 0            None              [start time, patient, concept, study]   2
# 1            None               [Images Id, patient, concept, study]   4
# 2            None  [Biosource ID, Diagnosis ID, Biomaterial ID, p...   7
# 3            None  [Biomaterial, Biosource, start time, Diagnosis...  10
#
#   secureObjectToken        studyId
# 0            PUBLIC  SYNTHETICMASS
# 1            PUBLIC         IMAGES
# 2            PUBLIC  Tumor Samples
# 3            PUBLIC            CSR

# %% [markdown]
# #### Get observation and subject counts for a given study

# %%
csr_study_constraint = atomic.StudyConstraint('CSR')
study_counts = api.observations.counts(constraint=csr_study_constraint)
study_counts
# Out:
# https://transmart.thehyve.net/v2/observations/counts
# {'observationCount': 341, 'patientCount': 17}

# %% [markdown]
# #### Get observation and subject counts for all studies

# %%
all_counts = api.observations.counts()
all_counts
# Out:
# https://transmart.thehyve.net/v2/observations/counts
# {'observationCount': 19227, 'patientCount': 1488}

# %% [markdown]
# #### Get ontology tree
#
# Visualize the tree structure up to _X_ levels deep

# %%
tree = api.tree_nodes(depth=5, counts=True)
tree
# Out:
# https://transmart.thehyve.net/v2/tree_nodes?depth=5&counts=True&tags=True
# Central Subject Registry  (None)/
#   01. Patient information  (None)/
#     01. Date of birth  (17)
#     02. Taxonomy  (None)
#     03. Gender  (17)
#     04. Date of death  (3)
#     Informed_consent  (None)/
#       01. Informed consent type  (17)
#       02. Date informed Consent given  (1)
#       03. Date informed consent withdrawn  (1)
#       04. Informed consent material  (None)
#       05. Informed consent data  (None)
#       06. Informed consent linking external database  (None)
#       07. Report hereditary susceptibility  (None)
#       Informed consent version  (None)
#   02. Diagnosis information  (None)/
#     01. Date of diagnosis  (17)
#     02. Tumor type  (17)
#     03. Topography  (17)
#     04. Tumor stage  (None)
#     05. Center of treatment  (17)
#     Treatment  (None)
#   03. Biosource information  (None)/
#     01. Biosource parent  (2)
#     02. Date of biosource  (17)
#     03. Tissue  (17)
#     04. Disease status  (17)
#     05. Tumor percentage  (17)
#     06. Biosource dedicated for specific study  (17)
#   04. Biomaterial information  (None)/
#     01. Biomaterial parent  (2)
#     02. Date of biomaterial  (17)
#     03. Biomaterial type  (17)
#   05. Study information  (None)/
#     01. Study ID  (17)
#     02. Study acronym  (17)
#     03. Study title  (17)
#     04. Individual Study ID  (None)
#     Study datadictionary  (17)
# Conditions  (None)/
#   ICD10  (None)/
#     Acute bronchitis [J20]  (414)
#     Acute pharyngitis [J02]  (None)/
#       Streptococcal pharyngitis [J02.0]  (137)
#     Alzheimer disease [G30]  (48)
#     Asthma [J45]  (36)
#     Atopic dermatitis [L20]  (28)
#     Burn and corrosion, body region unspecified [T30]  (None)/
#       Burn of first degree, body region unspecified [T30.1]  (28)
#       Burn of second degree, body region unspecified [T30.2]  (13)
#       Burn of third degree, body region unspecified [T30.3]  (1)
#     Cardiac arrest [I46]  (57)
#     Chronic ischaemic heart disease [I25]  (None)/
#       Atherosclerotic heart disease [I25.1]  (98)
#     Chronic sinusitis [J32]  (325)
#     Congenital malformations of uterus and cervix [Q51]  (None)/
#       Agenesis and aplasia of uterus [Q51.0]  (2)
#     Coxarthrosis [arthrosis of hip] [M16]  (None)/
#       Coxarthrosis, unspecified [M16.9]  (28)
#     Cystitis [N30]  (19)
#     Eclampsia [O15]  (None)/
#       Eclampsia in pregnancy [O15.0]  (13)
#     Ectopic pregnancy [O00]  (None)/
#       Tubal pregnancy [O00.1]  (2)
#     Emphysema [J43]  (None)/
#       Other emphysema [J43.8]  (47)
#     Epilepsy [G40]  (29)
#     Fracture of forearm [S52]  (None)/
#       Fracture of forearm, part unspecified [S52.9]  (36)
#     Fracture of rib(s), sternum and thoracic spine [S22]  (None)/
#       Fracture of rib [S22.3]  (16)
#     Fracture of shoulder and upper arm [S42]  (None)/
#       Fracture of clavicle [S42.0]  (37)
#     Gonarthrosis [arthrosis of knee] [M17]  (None)/
#       Gonarthrosis, unspecified [M17.9]  (54)
#     Gout [M10]  (None)/
#       Gout, unspecified [M10.9]  (8)
#     Intracranial injury [S06]  (None)/
#       Concussion [S06.0]  (11)
#     Malignant neoplasm of colon [C18]  (5)/
#       Malignant neoplasm: Overlapping lesion of colon [C18.8]  (None)
#     Osteoporosis with pathological fracture [M80]  (None)/
#       Other osteoporosis with pathological fracture [M80.8]  (None)/
#         Other osteoporosis with pathological fracture, forearm [M80.83]  (16)
#       Other osteoporosis with pathological fracture, forearm [M80.83]  (16)
#     Osteoporosis without pathological fracture [M81]  (None)/
#       Other osteoporosis [M81.8]  (82)
#     Other appendicitis [K36]  (73)
#     Other diseases of intestine [K63]  (None)/
#       Polyp of colon [K63.5]  (97)
#     Other rheumatoid arthritis [M06]  (None)/
#       Rheumatoid bursitis [M06.2]  (None)/
#         Rheumatoid bursitis, upper arm [M06.22]  (5)
#       Rheumatoid bursitis, upper arm [M06.22]  (5)
#     Pain, not elsewhere classified [R52]  (None)/
#       Other chronic pain [R52.2]  (7)
#     Pneumonia, organism unspecified [J18]  (13)
#     Pre-eclampsia [O14]  (12)
#     Stroke, not specified as haemorrhage or infarction [I64]  (107)
#     Supervision of normal pregnancy [Z34]  (139)
#     Suppurative and unspecified otitis media [H66]  (None)/
#       Otitis media, unspecified [H66.9]  (144)
#     Type 2 diabetes mellitus [E11]  (97)
#     Unspecified contact dermatitis [L25]  (9)
#     Unspecified diabetes mellitus [E14]  (None)/
#       Unspecified diabetes mellitus, with renal complications [E14.2]  (39)
#     Vasomotor and allergic rhinitis [J30]  (None)/
#       Other seasonal allergic rhinitis [J30.2]  (12)
#   SNOMED  (None)/
#     SNOMED CT Concept [138875005]  (None)/
#       Body structure [123037004]  (None)/
#         Morphologically altered structure [118956008]  (None)
#       Clinical finding [404684003]  (None)/
#         Bleeding [131148009]  (None)
#         Clinical history and observation findings [250171008]  (None)
#         Disease [64572001]  (None)
#         Edema [267038008]  (None)
#         Evaluation finding [441742003]  (None)
#         Fetal finding [106112009]  (None)
#         Finding by site [118234003]  (None)
#         Hypersensitivity condition [473010000]  (None)
#         Neurological finding [102957003]  (None)
#         Wound finding [225552003]  (None)
#       Situation with explicit context [243796009]  (None)/
#         Finding with explicit context [413350009]  (None)
#         Procedure with explicit context [129125009]  (None)
# Demographics  (None)/
#   Birthdate  (1462)
#   Birthplace  (1462)
#   Deathdate  (457)
#   Ethnicity  (1462)
#   Gender  (1462)
#   Marital  (1033)
#   Race  (1462)
# Public Studies  (None)/
#   IMAGES  (5)/
#     Demography  (None)/
#       Age  (5)
#       Gender  (5)
#     Images  (None)/
#       Tissue  (5)
#       Type  (5)
#   Tumor Samples  (9)/
#     01. Patient information  (None)/
#       01. Date of birth  (9)
#       02. Gender  (9)
#       05. Date of death  (None)
#       Informed consent  (None)/
#         01. Informed consent type  (9)
#         03. Date informed consent withdrawn  (1)
#         04. Informed consent material  (8)
#         05. Informed consent data  (6)
#         06. Informed concent linking external database  (1)
#         07. Report heriditary susceptibility  (9)
#       Taxonomy  (9)
#     02. Diagnosis information  (None)/
#       01. Date of diagnosis  (8)
#       02. Tumor type  (8)
#       03. Topography  (8)
#       04. Tumor stage  (8)
#       05. Center of treatment  (8)
#       Treatment  (8)
#     03. Biosource information  (None)/
#       01. Biosource parent  (8)
#       02. Date of biosource  (8)
#       03. Tissue  (8)
#       04. Disease status  (8)
#       05. Tumor percentage  (8)
#       06. Biosource dedicated for specific study  (3)
#     04. Biomaterial information  (None)/
#       01. Biomaterial parent  (2)
#       02. Date of biomaterial  (7)
#       03. Biomaterial type  (7)
#     05. Study information  (None)/
#       STD1  (None)/
#         01. Study ID  (5)
#         02. Study acronym  (5)
#         03. Study title  (5)
#         04. Individual Study ID  (5)
#       STD2  (None)/
#         01. Study ID  (5)
#         02. Study acronym  (5)
#         03. Study title  (5)
#         04. Individual Study ID  (5)

# %% [markdown]
# #### Get subtree
#
# Visualize tree structure only for a certain top node

# %%
tree = api.tree_nodes(root='\\Central Subject Registry\\', depth=3, counts=False)
tree
# Out:
# https://transmart.thehyve.net/v2/tree_nodes?root=\Central Subject Registry\&depth=3&counts=False&tags=True
# Central Subject Registry  (None)/
#   01. Patient information  (None)/
#     01. Date of birth  (None)
#     02. Taxonomy  (None)
#     03. Gender  (None)
#     04. Date of death  (None)
#     Informed_consent  (None)
#   02. Diagnosis information  (None)/
#     01. Date of diagnosis  (None)
#     02. Tumor type  (None)
#     03. Topography  (None)
#     04. Tumor stage  (None)
#     05. Center of treatment  (None)
#     Treatment  (None)
#   03. Biosource information  (None)/
#     01. Biosource parent  (None)
#     02. Date of biosource  (None)
#     03. Tissue  (None)
#     04. Disease status  (None)
#     05. Tumor percentage  (None)
#     06. Biosource dedicated for specific study  (None)
#   04. Biomaterial information  (None)/
#     01. Biomaterial parent  (None)
#     02. Date of biomaterial  (None)
#     03. Biomaterial type  (None)
#   05. Study information  (None)/
#     01. Study ID  (None)
#     02. Study acronym  (None)
#     03. Study title  (None)
#     04. Individual Study ID  (None)
#     Study datadictionary  (None)

# %% [markdown]
# ### Obtain list of tree nodes and corresponding concept codes

# %%
f1 = ~tree.dataframe['conceptCode'].isna()
f2 = ~tree.dataframe['conceptPath'].isna()
f = f1 & f2
ftree = tree.dataframe[f]
ftree = tree.dataframe[~tree.dataframe['conceptCode'].isna() ]

#display result (sorted by concept path)
concepts = ftree.loc[:, ['conceptPath', 'name', 'metadata.subject_dimension', 'conceptCode']].dropna(how='all').sort_values(by=['conceptPath'])
concepts
# Out:
#                                  conceptPath  \
# 23         \CSR\Biomaterial.biomaterial_date
# 22       \CSR\Biomaterial.src_biomaterial_id
# 24                     \CSR\Biomaterial.type
# 16             \CSR\Biosource.biosource_date
# 20        \CSR\Biosource.biosource_dedicated
# 18             \CSR\Biosource.disease_status
# 15           \CSR\Biosource.src_biosource_id
# 17                     \CSR\Biosource.tissue
# 19           \CSR\Biosource.tumor_percentage
# 12           \CSR\Diagnosis.center_treatment
# 8              \CSR\Diagnosis.diagnosis_date
# 10                 \CSR\Diagnosis.topography
# 13         \CSR\Diagnosis.treatment_protocol
# 11                \CSR\Diagnosis.tumor_stage
# 9                  \CSR\Diagnosis.tumor_type
# 2                 \CSR\Individual.birth_date
# 5                 \CSR\Individual.death_date
# 4                     \CSR\Individual.gender
# 3                   \CSR\Individual.taxonomy
# 29  \CSR\IndividualStudy.individual_study_id
# 27                        \CSR\Study.acronym
# 30                 \CSR\Study.datadictionary
# 26                       \CSR\Study.study_id
# 28                          \CSR\Study.title
#
#                                           name metadata.subject_dimension  \
# 23                     02. Date of biomaterial                Biomaterial
# 22                      01. Biomaterial parent                Biomaterial
# 24                        03. Biomaterial type                Biomaterial
# 16                       02. Date of biosource                  Biosource
# 20  06. Biosource dedicated for specific study                  Biosource
# 18                          04. Disease status                  Biosource
# 15                        01. Biosource parent                  Biosource
# 17                                  03. Tissue                  Biosource
# 19                        05. Tumor percentage                  Biosource
# 12                     05. Center of treatment                  Diagnosis
# 8                        01. Date of diagnosis                  Diagnosis
# 10                              03. Topography                  Diagnosis
# 13                                   Treatment                  Diagnosis
# 11                             04. Tumor stage                  Diagnosis
# 9                               02. Tumor type                  Diagnosis
# 2                            01. Date of birth                    patient
# 5                            04. Date of death                    patient
# 4                                   03. Gender                    patient
# 3                                 02. Taxonomy                    patient
# 29                     04. Individual Study ID            IndividualStudy
# 27                           02. Study acronym                      Study
# 30                        Study datadictionary                      Study
# 26                                01. Study ID                      Study
# 28                             03. Study title                      Study
#
#                             conceptCode
# 23         Biomaterial.biomaterial_date
# 22       Biomaterial.src_biomaterial_id
# 24                     Biomaterial.type
# 16             Biosource.biosource_date
# 20        Biosource.biosource_dedicated
# 18             Biosource.disease_status
# 15           Biosource.src_biosource_id
# 17                     Biosource.tissue
# 19           Biosource.tumor_percentage
# 12           Diagnosis.center_treatment
# 8              Diagnosis.diagnosis_date
# 10                 Diagnosis.topography
# 13         Diagnosis.treatment_protocol
# 11                Diagnosis.tumor_stage
# 9                  Diagnosis.tumor_type
# 2                 Individual.birth_date
# 5                 Individual.death_date
# 4                     Individual.gender
# 3                   Individual.taxonomy
# 29  IndividualStudy.individual_study_id
# 27                        Study.acronym
# 30                 Study.datadictionary
# 26                       Study.study_id
# 28                          Study.title

# %% [markdown]
# #### Get available values for a given concept
#
# Get aggregates for a given concept (e.g., value counts for a categorical concept)

# %%
tumor_type_concept_code = concepts[concepts['name']=='02. Tumor type']['conceptCode'].unique()[0]
tumor_type_constraint = atomic.ConceptCodeConstraint(tumor_type_concept_code)
aggregates_per_concept = api.observations.aggregates_per_concept(constraint=tumor_type_constraint)
print(json.dumps(aggregates_per_concept, indent=2))
# Out:
# https://transmart.thehyve.net/v2/observations/aggregates_per_concept
# {
#   "aggregatesPerConcept": {
#     "Diagnosis.tumor_type": {
#       "categoricalValueAggregates": {
#         "nullValueCounts": 0,
#         "valueCounts": {
#           "Angioimmunoblastic T-cell lymphoma": 7,
#           "Malignant lymphoma, non-Hodgkin": 12
#         }
#       }
#     }
#   }
# }

# %% [markdown]
# ### Querying observations

# %% [markdown]
# #### Query with a concept constraint
#
# Fetch aggregates for the gender concept

# %%
# find the concept code for the gender concept
gender_concept_code = concepts[concepts['name']=='03. Gender']['conceptCode'].unique()[0]
# Constraint: all gender observations
gender_constraint = api.new_constraint(concept=gender_concept_code)

print(json.dumps(api.observations.aggregates_per_concept(constraint=gender_constraint), indent=2))
print(api.observations.counts(constraint=gender_constraint))

# Display the first observation
display(api.observations(constraint=gender_constraint).dataframe.head(1))
# Out:
# https://transmart.thehyve.net/v2/observations/aggregates_per_concept
# {
#   "aggregatesPerConcept": {
#     "Individual.gender": {
#       "categoricalValueAggregates": {
#         "nullValueCounts": 0,
#         "valueCounts": {
#           "V": 3,
#           "female": 3,
#           "M": 3,
#           "male": 8
#         }
#       }
#     }
#   }
# }
# https://transmart.thehyve.net/v2/observations/counts
# {'observationCount': 17, 'patientCount': 17}
# https://transmart.thehyve.net/v2/observations
#   concept.conceptCode     concept.conceptPath concept.name patient.age  \
# 0   Individual.gender  \CSR\Individual.gender   03. Gender        None
#
#   patient.birthDate patient.deathDate  patient.id patient.inTrialId  \
# 0              None              None        1472              None
#
#   patient.maritalStatus patient.race patient.religion patient.sex  \
# 0                  None         None             None        male
#
#   patient.sexCd patient.subjectIds.SUBJ_ID patient.trial start time  \
# 0             M                       PAT1          None       None
#
#   stringValue study.name
# 0           M        CSR

# %% [markdown]
# #### Query with concept and value constraint
#
# Fetch observations for malignant lymphoma tumor type

# %%
# Constraint: all malignant lymphoma tumor type observations

malignant_lymphoma_constraint = api.new_constraint(concept=tumor_type_concept_code, value_list=['Malignant lymphoma, non-Hodgkin'])

print(api.observations.counts(constraint=malignant_lymphoma_constraint))
display(api.observations(constraint=malignant_lymphoma_constraint).dataframe.head())
# Out:
# https://transmart.thehyve.net/v2/observations/counts
# {'observationCount': 12, 'patientCount': 12}
# https://transmart.thehyve.net/v2/observations
#     concept.conceptCode        concept.conceptPath    concept.name  \
# 0  Diagnosis.tumor_type  \CSR\Diagnosis.tumor_type  02. Tumor type
# 1  Diagnosis.tumor_type  \CSR\Diagnosis.tumor_type  02. Tumor type
# 2  Diagnosis.tumor_type  \CSR\Diagnosis.tumor_type  02. Tumor type
# 3  Diagnosis.tumor_type  \CSR\Diagnosis.tumor_type  02. Tumor type
# 4  Diagnosis.tumor_type  \CSR\Diagnosis.tumor_type  02. Tumor type
#
#   patient.age patient.birthDate patient.deathDate  patient.id  \
# 0        None              None              None        1472
# 1        None              None              None        1473
# 2        None              None              None        1478
# 3        None              None              None        1480
# 4        None              None              None        1481
#
#   patient.inTrialId patient.maritalStatus patient.race patient.religion  \
# 0              None                  None         None             None
# 1              None                  None         None             None
# 2              None                  None         None             None
# 3              None                  None         None             None
# 4              None                  None         None             None
#
#   patient.sex patient.sexCd patient.subjectIds.SUBJ_ID patient.trial  \
# 0        male             M                       PAT1          None
# 1      female        female                      PAT13          None
# 2        male          male                      PAT10          None
# 3      female        female                      PAT12          None
# 4        male             M                       PAT2          None
#
#   start time                      stringValue study.name
# 0       None  Malignant lymphoma, non-Hodgkin        CSR
# 1       None  Malignant lymphoma, non-Hodgkin        CSR
# 2       None  Malignant lymphoma, non-Hodgkin        CSR
# 3       None  Malignant lymphoma, non-Hodgkin        CSR
# 4       None  Malignant lymphoma, non-Hodgkin        CSR

# %% [markdown]
# ### Query patients using observation constraints

# %% [markdown]
# #### Select patients using a concept constraint
#
# Select all patients with an observation for the gender concept

# %%
# Constraint: all patients with a gender observation
gender_constraint_sub = copy.copy(gender_constraint)
gender_constraint_sub.subselection = 'patient'

print(json.dumps(gender_constraint_sub.json(), indent=2))
print(api.observations.counts(constraint=gender_constraint_sub))

# Display first observation for the selected group of patients
display(api.observations(constraint=gender_constraint_sub).dataframe.head(1))
# Out:
# {
#   "type": "subselection",
#   "dimension": "patient",
#   "constraint": {
#     "type": "concept",
#     "conceptCode": "Individual.gender"
#   }
# }
# https://transmart.thehyve.net/v2/observations/counts
# {'observationCount': 341, 'patientCount': 17}
# https://transmart.thehyve.net/v2/observations
#   Biomaterial Biosource Diagnosis           concept.conceptCode  \
# 0       BIOM1     BIOS1      DIA1  Biomaterial.biomaterial_date
#
#                  concept.conceptPath             concept.name  numericValue  \
# 0  \CSR\Biomaterial.biomaterial_date  02. Date of biomaterial           NaN
#
#   patient.age patient.birthDate patient.deathDate  ...  patient.maritalStatus  \
# 0        None              None              None  ...                   None
#
#   patient.race patient.religion patient.sex patient.sexCd  \
# 0         None             None        male             M
#
#   patient.subjectIds.SUBJ_ID patient.trial start time stringValue study.name
# 0                       PAT1          None       None  2018-03-07        CSR
#
# [1 rows x 22 columns]

# %% [markdown]
# #### Select patients using concept and value constraint
#
# Select all patients with an observation for malignant lymphoma tumor type

# %%
# Constraint: all patients with an observation for malignant lymphoma tumor type
malignant_lymphoma_constraint_sub = copy.copy(malignant_lymphoma_constraint)
malignant_lymphoma_constraint_sub.subselection = 'patient'

print(json.dumps(malignant_lymphoma_constraint_sub.json(), indent=2))
print(api.observations.counts(constraint=malignant_lymphoma_constraint_sub))

# Display first observation for the selected group of patients
display(api.observations(constraint=malignant_lymphoma_constraint_sub).dataframe.head(1))
# Out:
# {
#   "type": "subselection",
#   "dimension": "patient",
#   "constraint": {
#     "args": [
#       {
#         "type": "concept",
#         "conceptCode": "Diagnosis.tumor_type"
#       },
#       {
#         "type": "value",
#         "valueType": "STRING",
#         "operator": "=",
#         "value": "Malignant lymphoma, non-Hodgkin"
#       }
#     ],
#     "type": "and"
#   }
# }
# https://transmart.thehyve.net/v2/observations/counts
# {'observationCount': 246, 'patientCount': 12}
# https://transmart.thehyve.net/v2/observations
#   Biomaterial Biosource Diagnosis           concept.conceptCode  \
# 0       BIOM1     BIOS1      DIA1  Biomaterial.biomaterial_date
#
#                  concept.conceptPath             concept.name  numericValue  \
# 0  \CSR\Biomaterial.biomaterial_date  02. Date of biomaterial           NaN
#
#   patient.age patient.birthDate patient.deathDate  ...  patient.maritalStatus  \
# 0        None              None              None  ...                   None
#
#   patient.race patient.religion patient.sex patient.sexCd  \
# 0         None             None        male             M
#
#   patient.subjectIds.SUBJ_ID patient.trial start time stringValue study.name
# 0                       PAT1          None       None  2018-03-07        CSR
#
# [1 rows x 22 columns]

# %% [markdown]
# #### Lookup concepts by path

# %%
# find concept by concept_path
gender_concept_path = '\\CSR\\Individual.gender'
gender_concept_code = concepts[concepts['conceptPath']==gender_concept_path]['conceptCode'].unique()[0]
gender_concept_code
# Out:
# 'Individual.gender'

# %%
gender_constraint = api.new_constraint(concept=gender_concept_code)

print(json.dumps(api.observations.aggregates_per_concept(constraint=gender_constraint), indent=2))
print(api.observations.counts(constraint=gender_constraint))
# Out:
# https://transmart.thehyve.net/v2/observations/aggregates_per_concept
# {
#   "aggregatesPerConcept": {
#     "Individual.gender": {
#       "categoricalValueAggregates": {
#         "nullValueCounts": 0,
#         "valueCounts": {
#           "V": 3,
#           "female": 3,
#           "M": 3,
#           "male": 8
#         }
#       }
#     }
#   }
# }
# https://transmart.thehyve.net/v2/observations/counts
# {'observationCount': 17, 'patientCount': 17}

# %% [markdown]
# ### Advanced queries
#
# Combine groups of patients with And (intersection) and Or (union) operators.

# %%
# Print all the possible parameters for a query constraint
for key in api.new_constraint().params:
    print("* {}".format(key))
# Out:
# * concept
# * study
# * trial_visit
# * min_value
# * max_value
# * min_date_value
# * max_date_value
# * value_list
# * min_start_date
# * max_start_date
# * subject_set_id

# %%
# Constraint: select all gender observations with value 'female'
all_females = api.new_constraint(concept=gender_concept_code, value_list=['female'])
# Constraint: select all gender observations with value 'male'
all_males = api.new_constraint(concept=gender_concept_code, value_list=['male'])

# %% [markdown]
# ### Query for women with a certain tumor type

# %%
# Constraint: women with malignant lymphoma
women_with_malignant_lymphoma = all_females & malignant_lymphoma_constraint

# Retrieve and print the counts for observations and patients matching our constraint
output = api.observations.counts(constraint=women_with_malignant_lymphoma)
print(json.dumps(output, indent=2))

# Retrieve the patients matching our constraint and displaying the first five
display(api.patients(constraint=women_with_malignant_lymphoma).dataframe.head())

# Retrieve the observations matching our constraint and displaying the first five
display(api.observations(constraint=women_with_malignant_lymphoma).dataframe.head())
# Out:
# https://transmart.thehyve.net/v2/observations/counts
# {
#   "observationCount": 40,
#   "patientCount": 2
# }
# https://transmart.thehyve.net/v2/patients
#     age birthDate deathDate    id inTrialId maritalStatus  race religion  \
# 0  None      None      None  1480      None          None  None     None
# 1  None      None      None  1473      None          None  None     None
#
#       sex subjectIds.SUBJ_ID trial
# 0  FEMALE              PAT12  None
# 1  FEMALE              PAT13  None
# https://transmart.thehyve.net/v2/observations
#   Biomaterial Biosource Diagnosis             concept.conceptCode  \
# 0      BIOM13    BIOS13     DIA13    Biomaterial.biomaterial_date
# 1      BIOM12    BIOS12     DIA12    Biomaterial.biomaterial_date
# 2      BIOM21    BIOS12     DIA12    Biomaterial.biomaterial_date
# 3      BIOM21    BIOS12     DIA12  Biomaterial.src_biomaterial_id
# 4      BIOM13    BIOS13     DIA13                Biomaterial.type
#
#                    concept.conceptPath             concept.name  numericValue  \
# 0    \CSR\Biomaterial.biomaterial_date  02. Date of biomaterial           NaN
# 1    \CSR\Biomaterial.biomaterial_date  02. Date of biomaterial           NaN
# 2    \CSR\Biomaterial.biomaterial_date  02. Date of biomaterial           NaN
# 3  \CSR\Biomaterial.src_biomaterial_id   01. Biomaterial parent           NaN
# 4                \CSR\Biomaterial.type     03. Biomaterial type           NaN
#
#   patient.age patient.birthDate patient.deathDate  ...  patient.maritalStatus  \
# 0        None              None              None  ...                   None
# 1        None              None              None  ...                   None
# 2        None              None              None  ...                   None
# 3        None              None              None  ...                   None
# 4        None              None              None  ...                   None
#
#   patient.race patient.religion patient.sex patient.sexCd  \
# 0         None             None      female        female
# 1         None             None      female        female
# 2         None             None      female        female
# 3         None             None      female        female
# 4         None             None      female        female
#
#   patient.subjectIds.SUBJ_ID patient.trial start time stringValue study.name
# 0                      PAT13          None       None  2018-03-07        CSR
# 1                      PAT12          None       None  2011-06-05        CSR
# 2                      PAT12          None       None  2011-06-05        CSR
# 3                      PAT12          None       None      BIOM12        CSR
# 4                      PAT13          None       None        mRNA        CSR
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Query for men with a certain tumor type

# %%
# Constraint: men with malignant lymphoma
men_with_malignant_lymphoma = all_males & malignant_lymphoma_constraint

# Retrieve and print the counts for observations and patients matching our constraint
output = api.observations.counts(constraint=men_with_malignant_lymphoma)
print(json.dumps(output, indent=2))

# Retrieve the patients matching our constraint and displaying the first five
display(api.patients(constraint=men_with_malignant_lymphoma).dataframe.head())

# Retrieve the observations matching our constraint and displaying the first five
display(api.observations(constraint=men_with_malignant_lymphoma).dataframe.head())
# Out:
# https://transmart.thehyve.net/v2/observations/counts
# {
#   "observationCount": 127,
#   "patientCount": 7
# }
# https://transmart.thehyve.net/v2/patients
#     age birthDate deathDate    id inTrialId maritalStatus  race religion  \
# 0  None      None      None  1487      None          None  None     None
# 1  None      None      None  1478      None          None  None     None
# 2  None      None      None  1486      None          None  None     None
# 3  None      None      None  1483      None          None  None     None
# 4  None      None      None  1485      None          None  None     None
#
#     sex subjectIds.SUBJ_ID trial
# 0  MALE               PAT8  None
# 1  MALE              PAT10  None
# 2  MALE               PAT7  None
# 3  MALE               PAT4  None
# 4  MALE               PAT6  None
# https://transmart.thehyve.net/v2/observations
#   Biomaterial Biosource Diagnosis           concept.conceptCode  \
# 0      BIOM10    BIOS10     DIA10  Biomaterial.biomaterial_date
# 1       BIOM4     BIOS4      DIA4  Biomaterial.biomaterial_date
# 2       BIOM5     BIOS5      DIA5  Biomaterial.biomaterial_date
# 3       BIOM6     BIOS6      DIA6  Biomaterial.biomaterial_date
# 4       BIOM7     BIOS7      DIA7  Biomaterial.biomaterial_date
#
#                  concept.conceptPath             concept.name  numericValue  \
# 0  \CSR\Biomaterial.biomaterial_date  02. Date of biomaterial           NaN
# 1  \CSR\Biomaterial.biomaterial_date  02. Date of biomaterial           NaN
# 2  \CSR\Biomaterial.biomaterial_date  02. Date of biomaterial           NaN
# 3  \CSR\Biomaterial.biomaterial_date  02. Date of biomaterial           NaN
# 4  \CSR\Biomaterial.biomaterial_date  02. Date of biomaterial           NaN
#
#   patient.age patient.birthDate patient.deathDate  ...  patient.maritalStatus  \
# 0        None              None              None  ...                   None
# 1        None              None              None  ...                   None
# 2        None              None              None  ...                   None
# 3        None              None              None  ...                   None
# 4        None              None              None  ...                   None
#
#   patient.race patient.religion patient.sex patient.sexCd  \
# 0         None             None        male          male
# 1         None             None        male          male
# 2         None             None        male          male
# 3         None             None        male          male
# 4         None             None        male          male
#
#   patient.subjectIds.SUBJ_ID patient.trial start time stringValue study.name
# 0                      PAT10          None       None  2018-03-07        CSR
# 1                       PAT4          None       None  2018-03-07        CSR
# 2                       PAT5          None       None  2011-06-05        CSR
# 3                       PAT6          None       None  2011-06-05        CSR
# 4                       PAT7          None       None  2018-03-07        CSR
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Combining groups with And (intersection)
#
# Create a constraint that selects individuals that are both in the male and female group.
# The result should be 0 patients/observations.

# %%
# Constraint: the intersection of men with malignant lymphoma and women with malignant lymphoma
both_male_and_female_with_malignant_lymphoma = women_with_malignant_lymphoma & copy.copy(men_with_malignant_lymphoma)

# Retrieve and print the counts for observations and patients matching our constraint
output = api.observations.counts(constraint=both_male_and_female_with_malignant_lymphoma)
print(json.dumps(output, indent=2))
# Out:
# https://transmart.thehyve.net/v2/observations/counts
# {
#   "observationCount": 0,
#   "patientCount": 0
# }

# %% [markdown]
# ### Combining groups with Or (union)
#
# Create a constraint that selects the union of all men, all women, and all patients diagnosed with malignant lymphoma.
# The result should include all patients/observations, because logic implies inclusion of patients that are male or female or have tumor.

# %%
# Constraint: the union of men, women and patients with malignant lymphoma
male_or_female_or_malignant_lymphoma = (all_females | all_males) | malignant_lymphoma_constraint

# Retrieve and print the counts for observations and patients matching our constraint
output = api.observations.counts(constraint=male_or_female_or_malignant_lymphoma)
print(json.dumps(output, indent=2))

# Retrieve the patients matching our constraint and displaying the first five
display(api.patients(constraint=male_or_female_or_malignant_lymphoma).dataframe.head())

# Retrieve the observations matching our constraint and displaying the first five
display(api.observations(constraint=male_or_female_or_malignant_lymphoma).dataframe.head())
# Out:
# https://transmart.thehyve.net/v2/observations/counts
# {
#   "observationCount": 287,
#   "patientCount": 14
# }
# https://transmart.thehyve.net/v2/patients
#     age birthDate deathDate    id inTrialId maritalStatus  race religion  \
# 0  None      None      None  1472      None          None  None     None
# 1  None      None      None  1473      None          None  None     None
# 2  None      None      None  1474      None          None  None     None
# 3  None      None      None  1478      None          None  None     None
# 4  None      None      None  1479      None          None  None     None
#
#       sex subjectIds.SUBJ_ID trial
# 0    MALE               PAT1  None
# 1  FEMALE              PAT13  None
# 2  FEMALE              PAT14  None
# 3    MALE              PAT10  None
# 4    MALE              PAT11  None
# https://transmart.thehyve.net/v2/observations
#   Biomaterial Biosource Diagnosis           concept.conceptCode  \
# 0       BIOM1     BIOS1      DIA1  Biomaterial.biomaterial_date
# 1      BIOM18    BIOS18     DIA18  Biomaterial.biomaterial_date
# 2      BIOM13    BIOS13     DIA13  Biomaterial.biomaterial_date
# 3      BIOM14    BIOS14     DIA14  Biomaterial.biomaterial_date
# 4      BIOM10    BIOS10     DIA10  Biomaterial.biomaterial_date
#
#                  concept.conceptPath             concept.name  numericValue  \
# 0  \CSR\Biomaterial.biomaterial_date  02. Date of biomaterial           NaN
# 1  \CSR\Biomaterial.biomaterial_date  02. Date of biomaterial           NaN
# 2  \CSR\Biomaterial.biomaterial_date  02. Date of biomaterial           NaN
# 3  \CSR\Biomaterial.biomaterial_date  02. Date of biomaterial           NaN
# 4  \CSR\Biomaterial.biomaterial_date  02. Date of biomaterial           NaN
#
#   patient.age patient.birthDate patient.deathDate  ...  patient.maritalStatus  \
# 0        None              None              None  ...                   None
# 1        None              None              None  ...                   None
# 2        None              None              None  ...                   None
# 3        None              None              None  ...                   None
# 4        None              None              None  ...                   None
#
#   patient.race patient.religion patient.sex patient.sexCd  \
# 0         None             None        male             M
# 1         None             None        male             M
# 2         None             None      female        female
# 3         None             None      female        female
# 4         None             None        male          male
#
#   patient.subjectIds.SUBJ_ID patient.trial start time stringValue study.name
# 0                       PAT1          None       None  2018-03-07        CSR
# 1                       PAT1          None       None  2011-06-05        CSR
# 2                      PAT13          None       None  2018-03-07        CSR
# 3                      PAT14          None       None  2011-06-05        CSR
# 4                      PAT10          None       None  2018-03-07        CSR
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Combine And with Or (intersection and union)
#
# Create a constraints that selects both women with malignant lymphoma and men with malignant lymphoma.

# %%
# Combine OR with AND: both women with a particular tumor type and men with the tumor type
all_with_malignant_lymphoma = women_with_malignant_lymphoma | men_with_malignant_lymphoma

# Print a representation of the constraint
#print(json.dumps(all_with_malignant_lymphoma.json(), indent=2))

# Retrieve and print the counts for observations and patients matching the constraint
output = api.observations.counts(constraint=all_with_malignant_lymphoma)
print(json.dumps(output, indent=2))

# Retrieve the patients matching the constraint and displaying the first five
display(api.patients(constraint=all_with_malignant_lymphoma).dataframe.head())

# Retrieve the observations matching the constraint and displaying the first five
display(api.observations(constraint=all_with_malignant_lymphoma).dataframe.head())
# Out:
# https://transmart.thehyve.net/v2/observations/counts
# {
#   "observationCount": 167,
#   "patientCount": 9
# }
# https://transmart.thehyve.net/v2/patients
#     age birthDate deathDate    id inTrialId maritalStatus  race religion  \
# 0  None      None      None  1473      None          None  None     None
# 1  None      None      None  1478      None          None  None     None
# 2  None      None      None  1480      None          None  None     None
# 3  None      None      None  1483      None          None  None     None
# 4  None      None      None  1484      None          None  None     None
#
#       sex subjectIds.SUBJ_ID trial
# 0  FEMALE              PAT13  None
# 1    MALE              PAT10  None
# 2  FEMALE              PAT12  None
# 3    MALE               PAT4  None
# 4    MALE               PAT5  None
# https://transmart.thehyve.net/v2/observations
#   Biomaterial Biosource Diagnosis           concept.conceptCode  \
# 0      BIOM13    BIOS13     DIA13  Biomaterial.biomaterial_date
# 1      BIOM10    BIOS10     DIA10  Biomaterial.biomaterial_date
# 2      BIOM12    BIOS12     DIA12  Biomaterial.biomaterial_date
# 3      BIOM21    BIOS12     DIA12  Biomaterial.biomaterial_date
# 4       BIOM4     BIOS4      DIA4  Biomaterial.biomaterial_date
#
#                  concept.conceptPath             concept.name  numericValue  \
# 0  \CSR\Biomaterial.biomaterial_date  02. Date of biomaterial           NaN
# 1  \CSR\Biomaterial.biomaterial_date  02. Date of biomaterial           NaN
# 2  \CSR\Biomaterial.biomaterial_date  02. Date of biomaterial           NaN
# 3  \CSR\Biomaterial.biomaterial_date  02. Date of biomaterial           NaN
# 4  \CSR\Biomaterial.biomaterial_date  02. Date of biomaterial           NaN
#
#   patient.age patient.birthDate patient.deathDate  ...  patient.maritalStatus  \
# 0        None              None              None  ...                   None
# 1        None              None              None  ...                   None
# 2        None              None              None  ...                   None
# 3        None              None              None  ...                   None
# 4        None              None              None  ...                   None
#
#   patient.race patient.religion patient.sex patient.sexCd  \
# 0         None             None      female        female
# 1         None             None        male          male
# 2         None             None      female        female
# 3         None             None      female        female
# 4         None             None        male          male
#
#   patient.subjectIds.SUBJ_ID patient.trial start time stringValue study.name
# 0                      PAT13          None       None  2018-03-07        CSR
# 1                      PAT10          None       None  2018-03-07        CSR
# 2                      PAT12          None       None  2011-06-05        CSR
# 3                      PAT12          None       None  2011-06-05        CSR
# 4                       PAT4          None       None  2018-03-07        CSR
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Specifying custom constraints in JSON format
#
# Use subselection to select biomaterials related to the eye tissue biosources
# (this leaves out the observations on patient, diagnosis and biosource level).

# %%
tissue_concept_code = concepts[concepts['name']=='03. Tissue']['conceptCode'].unique()[0]
tissue_constraint = api.new_constraint(concept=tissue_concept_code)

print('Tissue types:', api.observations(constraint=tissue_constraint).dataframe.stringValue.unique())
eye_tissue_constraint = api.new_constraint(concept=tissue_concept_code, value_list = ['eye'])
eye_tissue_constraint.subselection = 'Biosource'

# Retrieve and print the counts for observations and patients for eye tissue biosources
output = api.observations.counts(constraint=eye_tissue_constraint)
print(json.dumps(output, indent=2))

print(json.dumps(eye_tissue_constraint.json(), indent=2))

# Use subselection to select biomaterials related to the eye tissue biosources
# (this leaves out the observations on patient, diagnosis and biosource level)
# Note that this is a pure Python dictionary, not a constraint class from the transmart library.
eye_tissue_biomaterials_constraint = {
    'type': 'subselection',
    'dimension': 'Biomaterial',
    'constraint': eye_tissue_constraint.json()
}
output = api.observations.counts(constraint=eye_tissue_biomaterials_constraint)
print(json.dumps(output, indent=2))


display(api.observations(constraint=eye_tissue_biomaterials_constraint).dataframe.head())
# Out:
# https://transmart.thehyve.net/v2/observations
# Tissue types: ['eye' 'nerve']
# https://transmart.thehyve.net/v2/observations/counts
# {
#   "observationCount": 62,
#   "patientCount": 8
# }
# {
#   "type": "subselection",
#   "dimension": "Biosource",
#   "constraint": {
#     "args": [
#       {
#         "type": "concept",
#         "conceptCode": "Biosource.tissue"
#       },
#       {
#         "type": "value",
#         "valueType": "STRING",
#         "operator": "=",
#         "value": "eye"
#       }
#     ],
#     "type": "and"
#   }
# }
# https://transmart.thehyve.net/v2/observations/counts
# {
#   "observationCount": 22,
#   "patientCount": 8
# }
# https://transmart.thehyve.net/v2/observations
#   Biomaterial Biosource Diagnosis           concept.conceptCode  \
# 0       BIOM1     BIOS1      DIA1  Biomaterial.biomaterial_date
# 1      BIOM10    BIOS10     DIA10  Biomaterial.biomaterial_date
# 2      BIOM11    BIOS11     DIA11  Biomaterial.biomaterial_date
# 3      BIOM20    BIOS11     DIA11  Biomaterial.biomaterial_date
# 4      BIOM12    BIOS12     DIA12  Biomaterial.biomaterial_date
#
#                  concept.conceptPath             concept.name patient.age  \
# 0  \CSR\Biomaterial.biomaterial_date  02. Date of biomaterial        None
# 1  \CSR\Biomaterial.biomaterial_date  02. Date of biomaterial        None
# 2  \CSR\Biomaterial.biomaterial_date  02. Date of biomaterial        None
# 3  \CSR\Biomaterial.biomaterial_date  02. Date of biomaterial        None
# 4  \CSR\Biomaterial.biomaterial_date  02. Date of biomaterial        None
#
#   patient.birthDate patient.deathDate  patient.id  ... patient.maritalStatus  \
# 0              None              None        1472  ...                  None
# 1              None              None        1478  ...                  None
# 2              None              None        1479  ...                  None
# 3              None              None        1479  ...                  None
# 4              None              None        1480  ...                  None
#
#   patient.race patient.religion patient.sex patient.sexCd  \
# 0         None             None        male             M
# 1         None             None        male          male
# 2         None             None        male          male
# 3         None             None        male          male
# 4         None             None      female        female
#
#   patient.subjectIds.SUBJ_ID patient.trial start time stringValue study.name
# 0                       PAT1          None       None  2018-03-07        CSR
# 1                      PAT10          None       None  2018-03-07        CSR
# 2                      PAT11          None       None  2011-06-05        CSR
# 3                      PAT11          None       None  2011-06-05        CSR
# 4                      PAT12          None       None  2011-06-05        CSR
#
# [5 rows x 21 columns]
