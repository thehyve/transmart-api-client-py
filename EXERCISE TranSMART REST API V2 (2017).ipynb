# %%
import getpass
from transmart_api import TransmartApi

api = TransmartApi(
    host = 'http://transmart-pro-acc.thehyve.net',
    user = input('Username:'),
    password = getpass.getpass('Password:'),
    apiversion = 2)

api.access()
# Out:
# Username:admin
# Password:········
# 'SUCCESS'

# %%
study_id = 'GSE8581'
obs = api.get_observations(study = study_id)

# %%
obs
# Out:
# {'cells': [{'dimensionIndexes': [0, 0, 0, 0],
#    'inlineDimensions': [],
#    'numericValue': 1.41},
#   {'dimensionIndexes': [0, 0, 1, 0],
#    'inlineDimensions': [],
#    'numericValue': 51.0},
#   {'dimensionIndexes': [0, 0, 2, 1],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 1],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 4, 1],
#    'inlineDimensions': [],
#    'stringValue': 'female'},
#   {'dimensionIndexes': [0, 0, 5, 1],
#    'inlineDimensions': [],
#    'numericValue': 50.0},
#   {'dimensionIndexes': [0, 0, 6, 1],
#    'inlineDimensions': [],
#    'numericValue': 65.0},
#   {'dimensionIndexes': [0, 0, 7, 1],
#    'inlineDimensions': [],
#    'stringValue': 'control'},
#   {'dimensionIndexes': [0, 0, 8, 1],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell adenocarcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 1],
#    'inlineDimensions': [],
#    'numericValue': 2.31},
#   {'dimensionIndexes': [0, 0, 1, 1],
#    'inlineDimensions': [],
#    'numericValue': 75.0},
#   {'dimensionIndexes': [0, 0, 2, 2],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 2],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 4, 2],
#    'inlineDimensions': [],
#    'stringValue': 'female'},
#   {'dimensionIndexes': [0, 0, 5, 2],
#    'inlineDimensions': [],
#    'numericValue': 68.0},
#   {'dimensionIndexes': [0, 0, 6, 2],
#    'inlineDimensions': [],
#    'numericValue': 65.0},
#   {'dimensionIndexes': [0, 0, 7, 2],
#    'inlineDimensions': [],
#    'stringValue': 'control'},
#   {'dimensionIndexes': [0, 0, 8, 2],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell adenocarcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 2],
#    'inlineDimensions': [],
#    'numericValue': 2.59},
#   {'dimensionIndexes': [0, 0, 1, 2],
#    'inlineDimensions': [],
#    'numericValue': 74.0},
#   {'dimensionIndexes': [0, 0, 2, 3],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 3],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 4, 3],
#    'inlineDimensions': [],
#    'stringValue': 'female'},
#   {'dimensionIndexes': [0, 0, 5, 3],
#    'inlineDimensions': [],
#    'numericValue': 55.0},
#   {'dimensionIndexes': [0, 0, 6, 3],
#    'inlineDimensions': [],
#    'numericValue': 63.0},
#   {'dimensionIndexes': [0, 0, 7, 3],
#    'inlineDimensions': [],
#    'stringValue': 'control'},
#   {'dimensionIndexes': [0, 0, 8, 3],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell adenocarcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 3],
#    'inlineDimensions': [],
#    'numericValue': 2.17},
#   {'dimensionIndexes': [0, 0, 1, 3],
#    'inlineDimensions': [],
#    'numericValue': 76.0},
#   {'dimensionIndexes': [0, 0, 2, 4],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 4],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 9, 4],
#    'inlineDimensions': [],
#    'stringValue': 'male'},
#   {'dimensionIndexes': [0, 0, 5, 4],
#    'inlineDimensions': [],
#    'numericValue': 68.0},
#   {'dimensionIndexes': [0, 0, 6, 4],
#    'inlineDimensions': [],
#    'numericValue': 65.0},
#   {'dimensionIndexes': [0, 0, 7, 4],
#    'inlineDimensions': [],
#    'stringValue': 'control'},
#   {'dimensionIndexes': [0, 0, 8, 4],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell adenocarcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 4],
#    'inlineDimensions': [],
#    'numericValue': 2.59},
#   {'dimensionIndexes': [0, 0, 1, 4],
#    'inlineDimensions': [],
#    'numericValue': 74.0},
#   {'dimensionIndexes': [0, 0, 2, 5],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 5],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 4, 5],
#    'inlineDimensions': [],
#    'stringValue': 'female'},
#   {'dimensionIndexes': [0, 0, 5, 5],
#    'inlineDimensions': [],
#    'numericValue': 71.0},
#   {'dimensionIndexes': [0, 0, 6, 5],
#    'inlineDimensions': [],
#    'numericValue': 63.0},
#   {'dimensionIndexes': [0, 0, 7, 5],
#    'inlineDimensions': [],
#    'stringValue': 'control'},
#   {'dimensionIndexes': [0, 0, 8, 5],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell adenocarcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 5],
#    'inlineDimensions': [],
#    'numericValue': 1.98},
#   {'dimensionIndexes': [0, 0, 1, 5],
#    'inlineDimensions': [],
#    'numericValue': 78.0},
#   {'dimensionIndexes': [0, 0, 2, 6],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 10, 6],
#    'inlineDimensions': [],
#    'stringValue': 'Afro American'},
#   {'dimensionIndexes': [0, 0, 4, 6],
#    'inlineDimensions': [],
#    'stringValue': 'female'},
#   {'dimensionIndexes': [0, 0, 5, 6],
#    'inlineDimensions': [],
#    'numericValue': 84.0},
#   {'dimensionIndexes': [0, 0, 6, 6],
#    'inlineDimensions': [],
#    'numericValue': 60.0},
#   {'dimensionIndexes': [0, 0, 7, 6],
#    'inlineDimensions': [],
#    'stringValue': 'control'},
#   {'dimensionIndexes': [0, 0, 8, 6],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell adenocarcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 6],
#    'inlineDimensions': [],
#    'numericValue': 1.69},
#   {'dimensionIndexes': [0, 0, 1, 6],
#    'inlineDimensions': [],
#    'numericValue': 83.66},
#   {'dimensionIndexes': [0, 0, 2, 7],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 7],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 4, 7],
#    'inlineDimensions': [],
#    'stringValue': 'female'},
#   {'dimensionIndexes': [0, 0, 5, 7],
#    'inlineDimensions': [],
#    'numericValue': 61.0},
#   {'dimensionIndexes': [0, 0, 6, 7],
#    'inlineDimensions': [],
#    'numericValue': 60.0},
#   {'dimensionIndexes': [0, 0, 11, 7],
#    'inlineDimensions': [],
#    'stringValue': 'not specified'},
#   {'dimensionIndexes': [0, 0, 8, 7],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell adenocarcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 7],
#    'inlineDimensions': [],
#    'numericValue': 1.44},
#   {'dimensionIndexes': [0, 0, 1, 7],
#    'inlineDimensions': [],
#    'numericValue': 86.0},
#   {'dimensionIndexes': [0, 0, 2, 8],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 8],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 9, 8],
#    'inlineDimensions': [],
#    'stringValue': 'male'},
#   {'dimensionIndexes': [0, 0, 5, 8],
#    'inlineDimensions': [],
#    'numericValue': 61.0},
#   {'dimensionIndexes': [0, 0, 6, 8],
#    'inlineDimensions': [],
#    'numericValue': 69.0},
#   {'dimensionIndexes': [0, 0, 11, 8],
#    'inlineDimensions': [],
#    'stringValue': 'not specified'},
#   {'dimensionIndexes': [0, 0, 8, 8],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell adenocarcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 8],
#    'inlineDimensions': [],
#    'numericValue': 2.76},
#   {'dimensionIndexes': [0, 0, 1, 8],
#    'inlineDimensions': [],
#    'numericValue': 70.58},
#   {'dimensionIndexes': [0, 0, 2, 9],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 9],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 9, 9],
#    'inlineDimensions': [],
#    'stringValue': 'male'},
#   {'dimensionIndexes': [0, 0, 5, 9],
#    'inlineDimensions': [],
#    'numericValue': 79.0},
#   {'dimensionIndexes': [0, 0, 6, 9],
#    'inlineDimensions': [],
#    'numericValue': 69.0},
#   {'dimensionIndexes': [0, 0, 11, 9],
#    'inlineDimensions': [],
#    'stringValue': 'not specified'},
#   {'dimensionIndexes': [0, 0, 8, 9],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell adenocarcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 9],
#    'inlineDimensions': [],
#    'numericValue': 2.12},
#   {'dimensionIndexes': [0, 0, 1, 9],
#    'inlineDimensions': [],
#    'numericValue': 73.0},
#   {'dimensionIndexes': [0, 0, 2, 10],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 10],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 4, 10],
#    'inlineDimensions': [],
#    'stringValue': 'female'},
#   {'dimensionIndexes': [0, 0, 5, 10],
#    'inlineDimensions': [],
#    'numericValue': 73.0},
#   {'dimensionIndexes': [0, 0, 6, 10],
#    'inlineDimensions': [],
#    'numericValue': 66.0},
#   {'dimensionIndexes': [0, 0, 11, 10],
#    'inlineDimensions': [],
#    'stringValue': 'not specified'},
#   {'dimensionIndexes': [0, 0, 8, 10],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell adenocarcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 10],
#    'inlineDimensions': [],
#    'numericValue': 1.53},
#   {'dimensionIndexes': [0, 0, 1, 10],
#    'inlineDimensions': [],
#    'numericValue': 74.0},
#   {'dimensionIndexes': [0, 0, 2, 11],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 11],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 4, 11],
#    'inlineDimensions': [],
#    'stringValue': 'female'},
#   {'dimensionIndexes': [0, 0, 5, 11],
#    'inlineDimensions': [],
#    'numericValue': 77.0},
#   {'dimensionIndexes': [0, 0, 6, 11],
#    'inlineDimensions': [],
#    'numericValue': 63.0},
#   {'dimensionIndexes': [0, 0, 11, 11],
#    'inlineDimensions': [],
#    'stringValue': 'not specified'},
#   {'dimensionIndexes': [0, 0, 8, 11],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell adenocarcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 11],
#    'inlineDimensions': [],
#    'numericValue': 1.45},
#   {'dimensionIndexes': [0, 0, 1, 11],
#    'inlineDimensions': [],
#    'numericValue': 73.0},
#   {'dimensionIndexes': [0, 0, 2, 12],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 12],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 9, 12],
#    'inlineDimensions': [],
#    'stringValue': 'male'},
#   {'dimensionIndexes': [0, 0, 5, 12],
#    'inlineDimensions': [],
#    'numericValue': 46.0},
#   {'dimensionIndexes': [0, 0, 6, 12],
#    'inlineDimensions': [],
#    'numericValue': 66.0},
#   {'dimensionIndexes': [0, 0, 11, 12],
#    'inlineDimensions': [],
#    'stringValue': 'not specified'},
#   {'dimensionIndexes': [0, 0, 8, 12],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell adenocarcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 12],
#    'inlineDimensions': [],
#    'numericValue': 2.51},
#   {'dimensionIndexes': [0, 0, 1, 12],
#    'inlineDimensions': [],
#    'numericValue': 80.96},
#   {'dimensionIndexes': [0, 0, 2, 13],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 13],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 4, 13],
#    'inlineDimensions': [],
#    'stringValue': 'female'},
#   {'dimensionIndexes': [0, 0, 5, 13],
#    'inlineDimensions': [],
#    'numericValue': 81.0},
#   {'dimensionIndexes': [0, 0, 6, 13],
#    'inlineDimensions': [],
#    'numericValue': 66.0},
#   {'dimensionIndexes': [0, 0, 11, 13],
#    'inlineDimensions': [],
#    'stringValue': 'not specified'},
#   {'dimensionIndexes': [0, 0, 12, 13],
#    'inlineDimensions': [],
#    'stringValue': 'no malignancy'},
#   {'dimensionIndexes': [0, 0, 0, 13],
#    'inlineDimensions': [],
#    'numericValue': 1.6},
#   {'dimensionIndexes': [0, 0, 1, 13],
#    'inlineDimensions': [],
#    'numericValue': 77.0},
#   {'dimensionIndexes': [0, 0, 2, 14],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 14],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 4, 14],
#    'inlineDimensions': [],
#    'stringValue': 'female'},
#   {'dimensionIndexes': [0, 0, 5, 14],
#    'inlineDimensions': [],
#    'numericValue': 78.0},
#   {'dimensionIndexes': [0, 0, 6, 14],
#    'inlineDimensions': [],
#    'numericValue': 63.0},
#   {'dimensionIndexes': [0, 0, 7, 14],
#    'inlineDimensions': [],
#    'stringValue': 'control'},
#   {'dimensionIndexes': [0, 0, 13, 14],
#    'inlineDimensions': [],
#    'stringValue': 'metastatic renal cell carcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 14],
#    'inlineDimensions': [],
#    'numericValue': 1.99},
#   {'dimensionIndexes': [0, 0, 1, 14],
#    'inlineDimensions': [],
#    'numericValue': 85.0},
#   {'dimensionIndexes': [0, 0, 2, 15],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 15],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 4, 15],
#    'inlineDimensions': [],
#    'stringValue': 'female'},
#   {'dimensionIndexes': [0, 0, 5, 15],
#    'inlineDimensions': [],
#    'numericValue': 65.0},
#   {'dimensionIndexes': [0, 0, 6, 15],
#    'inlineDimensions': [],
#    'numericValue': 63.0},
#   {'dimensionIndexes': [0, 0, 11, 15],
#    'inlineDimensions': [],
#    'stringValue': 'not specified'},
#   {'dimensionIndexes': [0, 0, 14, 15],
#    'inlineDimensions': [],
#    'stringValue': 'metastatic non-small cell adenocarcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 15],
#    'inlineDimensions': [],
#    'numericValue': 1.2},
#   {'dimensionIndexes': [0, 0, 1, 15],
#    'inlineDimensions': [],
#    'numericValue': 72.0},
#   {'dimensionIndexes': [0, 0, 2, 16],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 16],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 9, 16],
#    'inlineDimensions': [],
#    'stringValue': 'male'},
#   {'dimensionIndexes': [0, 0, 5, 16],
#    'inlineDimensions': [],
#    'numericValue': 55.0},
#   {'dimensionIndexes': [0, 0, 6, 16],
#    'inlineDimensions': [],
#    'numericValue': 69.0},
#   {'dimensionIndexes': [0, 0, 7, 16],
#    'inlineDimensions': [],
#    'stringValue': 'control'},
#   {'dimensionIndexes': [0, 0, 15, 16],
#    'inlineDimensions': [],
#    'stringValue': 'inflammation'},
#   {'dimensionIndexes': [0, 0, 0, 16],
#    'inlineDimensions': [],
#    'numericValue': 4.04},
#   {'dimensionIndexes': [0, 0, 1, 16],
#    'inlineDimensions': [],
#    'numericValue': 79.0},
#   {'dimensionIndexes': [0, 0, 2, 17],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 17],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 9, 17],
#    'inlineDimensions': [],
#    'stringValue': 'male'},
#   {'dimensionIndexes': [0, 0, 5, 17],
#    'inlineDimensions': [],
#    'numericValue': 50.0},
#   {'dimensionIndexes': [0, 0, 6, 17],
#    'inlineDimensions': [],
#    'numericValue': 72.0},
#   {'dimensionIndexes': [0, 0, 11, 17],
#    'inlineDimensions': [],
#    'stringValue': 'not specified'},
#   {'dimensionIndexes': [0, 0, 16, 17],
#    'inlineDimensions': [],
#    'stringValue': 'hematoma'},
#   {'dimensionIndexes': [0, 0, 0, 17],
#    'inlineDimensions': [],
#    'numericValue': 4.08},
#   {'dimensionIndexes': [0, 0, 1, 17],
#    'inlineDimensions': [],
#    'numericValue': 68.0},
#   {'dimensionIndexes': [0, 0, 2, 18],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 18],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 9, 18],
#    'inlineDimensions': [],
#    'stringValue': 'male'},
#   {'dimensionIndexes': [0, 0, 5, 18],
#    'inlineDimensions': [],
#    'numericValue': 61.0},
#   {'dimensionIndexes': [0, 0, 6, 18],
#    'inlineDimensions': [],
#    'numericValue': 73.0},
#   {'dimensionIndexes': [0, 0, 17, 18],
#    'inlineDimensions': [],
#    'stringValue': 'chronic obstructive pulmonary disease'},
#   {'dimensionIndexes': [0, 0, 18, 18],
#    'inlineDimensions': [],
#    'stringValue': 'giant bullae'},
#   {'dimensionIndexes': [0, 0, 0, 18],
#    'inlineDimensions': [],
#    'numericValue': 0.4},
#   {'dimensionIndexes': [0, 0, 1, 18],
#    'inlineDimensions': [],
#    'numericValue': 45.0},
#   {'dimensionIndexes': [0, 0, 2, 19],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 19],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 9, 19],
#    'inlineDimensions': [],
#    'stringValue': 'male'},
#   {'dimensionIndexes': [0, 0, 5, 19],
#    'inlineDimensions': [],
#    'numericValue': 68.0},
#   {'dimensionIndexes': [0, 0, 6, 19],
#    'inlineDimensions': [],
#    'numericValue': 67.0},
#   {'dimensionIndexes': [0, 0, 17, 19],
#    'inlineDimensions': [],
#    'stringValue': 'chronic obstructive pulmonary disease'},
#   {'dimensionIndexes': [0, 0, 19, 19],
#    'inlineDimensions': [],
#    'stringValue': 'emphysema'},
#   {'dimensionIndexes': [0, 0, 0, 19],
#    'inlineDimensions': [],
#    'numericValue': 1.16},
#   {'dimensionIndexes': [0, 0, 1, 19],
#    'inlineDimensions': [],
#    'numericValue': 43.0},
#   {'dimensionIndexes': [0, 0, 2, 20],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 20],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 9, 20],
#    'inlineDimensions': [],
#    'stringValue': 'male'},
#   {'dimensionIndexes': [0, 0, 5, 20],
#    'inlineDimensions': [],
#    'numericValue': 40.0},
#   {'dimensionIndexes': [0, 0, 6, 20],
#    'inlineDimensions': [],
#    'numericValue': 67.0},
#   {'dimensionIndexes': [0, 0, 7, 20],
#    'inlineDimensions': [],
#    'stringValue': 'control'},
#   {'dimensionIndexes': [0, 0, 20, 20],
#    'inlineDimensions': [],
#    'stringValue': 'carcinoid'},
#   {'dimensionIndexes': [0, 0, 0, 20],
#    'inlineDimensions': [],
#    'numericValue': 3.7},
#   {'dimensionIndexes': [0, 0, 1, 20],
#    'inlineDimensions': [],
#    'numericValue': 81.86},
#   {'dimensionIndexes': [0, 0, 2, 21],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 21],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 9, 21],
#    'inlineDimensions': [],
#    'stringValue': 'male'},
#   {'dimensionIndexes': [0, 0, 5, 21],
#    'inlineDimensions': [],
#    'numericValue': 71.0},
#   {'dimensionIndexes': [0, 0, 6, 21],
#    'inlineDimensions': [],
#    'numericValue': 69.0},
#   {'dimensionIndexes': [0, 0, 11, 21],
#    'inlineDimensions': [],
#    'stringValue': 'not specified'},
#   {'dimensionIndexes': [0, 0, 20, 21],
#    'inlineDimensions': [],
#    'stringValue': 'carcinoid'},
#   {'dimensionIndexes': [0, 0, 0, 21],
#    'inlineDimensions': [],
#    'numericValue': 2.32},
#   {'dimensionIndexes': [0, 0, 1, 21],
#    'inlineDimensions': [],
#    'numericValue': 76.0},
#   {'dimensionIndexes': [0, 0, 2, 22],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 22],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 4, 22],
#    'inlineDimensions': [],
#    'stringValue': 'female'},
#   {'dimensionIndexes': [0, 0, 5, 22],
#    'inlineDimensions': [],
#    'numericValue': 64.0},
#   {'dimensionIndexes': [0, 0, 6, 22],
#    'inlineDimensions': [],
#    'numericValue': 63.0},
#   {'dimensionIndexes': [0, 0, 11, 22],
#    'inlineDimensions': [],
#    'stringValue': 'not specified'},
#   {'dimensionIndexes': [0, 0, 20, 22],
#    'inlineDimensions': [],
#    'stringValue': 'carcinoid'},
#   {'dimensionIndexes': [0, 0, 0, 22],
#    'inlineDimensions': [],
#    'numericValue': 1.69},
#   {'dimensionIndexes': [0, 0, 1, 22],
#    'inlineDimensions': [],
#    'numericValue': 76.0},
#   {'dimensionIndexes': [0, 0, 2, 23],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 23],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 9, 23],
#    'inlineDimensions': [],
#    'stringValue': 'male'},
#   {'dimensionIndexes': [0, 0, 5, 23],
#    'inlineDimensions': [],
#    'numericValue': 75.0},
#   {'dimensionIndexes': [0, 0, 6, 23],
#    'inlineDimensions': [],
#    'numericValue': 63.0},
#   {'dimensionIndexes': [0, 0, 17, 23],
#    'inlineDimensions': [],
#    'stringValue': 'chronic obstructive pulmonary disease'},
#   {'dimensionIndexes': [0, 0, 8, 23],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell adenocarcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 23],
#    'inlineDimensions': [],
#    'numericValue': 0.67},
#   {'dimensionIndexes': [0, 0, 1, 23],
#    'inlineDimensions': [],
#    'numericValue': 42.0},
#   {'dimensionIndexes': [0, 0, 2, 24],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 24],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 4, 24],
#    'inlineDimensions': [],
#    'stringValue': 'female'},
#   {'dimensionIndexes': [0, 0, 5, 24],
#    'inlineDimensions': [],
#    'numericValue': 52.0},
#   {'dimensionIndexes': [0, 0, 6, 24],
#    'inlineDimensions': [],
#    'numericValue': 66.0},
#   {'dimensionIndexes': [0, 0, 17, 24],
#    'inlineDimensions': [],
#    'stringValue': 'chronic obstructive pulmonary disease'},
#   {'dimensionIndexes': [0, 0, 21, 24],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell squamous cell carcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 24],
#    'inlineDimensions': [],
#    'numericValue': 0.88},
#   {'dimensionIndexes': [0, 0, 1, 24],
#    'inlineDimensions': [],
#    'numericValue': 52.0},
#   {'dimensionIndexes': [0, 0, 2, 25],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 25],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 4, 25],
#    'inlineDimensions': [],
#    'stringValue': 'female'},
#   {'dimensionIndexes': [0, 0, 5, 25],
#    'inlineDimensions': [],
#    'numericValue': 72.0},
#   {'dimensionIndexes': [0, 0, 6, 25],
#    'inlineDimensions': [],
#    'numericValue': 60.0},
#   {'dimensionIndexes': [0, 0, 17, 25],
#    'inlineDimensions': [],
#    'stringValue': 'chronic obstructive pulmonary disease'},
#   {'dimensionIndexes': [0, 0, 22, 25],
#    'inlineDimensions': [],
#    'stringValue': 'Giant Cell Tumor'},
#   {'dimensionIndexes': [0, 0, 0, 25],
#    'inlineDimensions': [],
#    'numericValue': 0.99},
#   {'dimensionIndexes': [0, 0, 1, 25],
#    'inlineDimensions': [],
#    'numericValue': 63.0},
#   {'dimensionIndexes': [0, 0, 2, 26],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 26],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 4, 26],
#    'inlineDimensions': [],
#    'stringValue': 'female'},
#   {'dimensionIndexes': [0, 0, 5, 26],
#    'inlineDimensions': [],
#    'numericValue': 54.0},
#   {'dimensionIndexes': [0, 0, 6, 26],
#    'inlineDimensions': [],
#    'numericValue': 75.0},
#   {'dimensionIndexes': [0, 0, 7, 26],
#    'inlineDimensions': [],
#    'stringValue': 'control'},
#   {'dimensionIndexes': [0, 0, 21, 26],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell squamous cell carcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 26],
#    'inlineDimensions': [],
#    'numericValue': 2.83},
#   {'dimensionIndexes': [0, 0, 1, 26],
#    'inlineDimensions': [],
#    'numericValue': 75.0},
#   {'dimensionIndexes': [0, 0, 2, 27],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 27],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 9, 27],
#    'inlineDimensions': [],
#    'stringValue': 'male'},
#   {'dimensionIndexes': [0, 0, 5, 27],
#    'inlineDimensions': [],
#    'numericValue': 78.0},
#   {'dimensionIndexes': [0, 0, 6, 27],
#    'inlineDimensions': [],
#    'numericValue': 70.0},
#   {'dimensionIndexes': [0, 0, 7, 27],
#    'inlineDimensions': [],
#    'stringValue': 'control'},
#   {'dimensionIndexes': [0, 0, 23, 27],
#    'inlineDimensions': [],
#    'stringValue': 'NSC-Mixed'},
#   {'dimensionIndexes': [0, 0, 0, 27],
#    'inlineDimensions': [],
#    'numericValue': 3.66},
#   {'dimensionIndexes': [0, 0, 1, 27],
#    'inlineDimensions': [],
#    'numericValue': 78.0},
#   {'dimensionIndexes': [0, 0, 2, 28],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 28],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 4, 28],
#    'inlineDimensions': [],
#    'stringValue': 'female'},
#   {'dimensionIndexes': [0, 0, 5, 28],
#    'inlineDimensions': [],
#    'numericValue': 62.0},
#   {'dimensionIndexes': [0, 0, 6, 28],
#    'inlineDimensions': [],
#    'numericValue': 62.0},
#   {'dimensionIndexes': [0, 0, 7, 28],
#    'inlineDimensions': [],
#    'stringValue': 'control'},
#   {'dimensionIndexes': [0, 0, 21, 28],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell squamous cell carcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 28],
#    'inlineDimensions': [],
#    'numericValue': 1.94},
#   {'dimensionIndexes': [0, 0, 1, 28],
#    'inlineDimensions': [],
#    'numericValue': 86.0},
#   {'dimensionIndexes': [0, 0, 2, 29],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 29],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 4, 29],
#    'inlineDimensions': [],
#    'stringValue': 'female'},
#   {'dimensionIndexes': [0, 0, 5, 29],
#    'inlineDimensions': [],
#    'numericValue': 59.0},
#   {'dimensionIndexes': [0, 0, 6, 29],
#    'inlineDimensions': [],
#    'numericValue': 69.0},
#   {'dimensionIndexes': [0, 0, 7, 29],
#    'inlineDimensions': [],
#    'stringValue': 'control'},
#   {'dimensionIndexes': [0, 0, 21, 29],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell squamous cell carcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 29],
#    'inlineDimensions': [],
#    'numericValue': 2.68},
#   {'dimensionIndexes': [0, 0, 4, 30],
#    'inlineDimensions': [],
#    'stringValue': 'female'},
#   {'dimensionIndexes': [0, 0, 1, 29],
#    'inlineDimensions': [],
#    'numericValue': 71.0},
#   {'dimensionIndexes': [0, 0, 2, 30],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 30],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 5, 30],
#    'inlineDimensions': [],
#    'numericValue': 77.0},
#   {'dimensionIndexes': [0, 0, 6, 30],
#    'inlineDimensions': [],
#    'numericValue': 58.0},
#   {'dimensionIndexes': [0, 0, 7, 30],
#    'inlineDimensions': [],
#    'stringValue': 'control'},
#   {'dimensionIndexes': [0, 0, 21, 30],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell squamous cell carcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 30],
#    'inlineDimensions': [],
#    'numericValue': 1.37},
#   {'dimensionIndexes': [0, 0, 1, 30],
#    'inlineDimensions': [],
#    'numericValue': 82.0},
#   {'dimensionIndexes': [0, 0, 2, 31],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 4, 31],
#    'inlineDimensions': [],
#    'stringValue': 'female'},
#   {'dimensionIndexes': [0, 0, 5, 31],
#    'inlineDimensions': [],
#    'numericValue': 71.0},
#   {'dimensionIndexes': [0, 0, 6, 31],
#    'inlineDimensions': [],
#    'numericValue': 66.0},
#   {'dimensionIndexes': [0, 0, 7, 31],
#    'inlineDimensions': [],
#    'stringValue': 'control'},
#   {'dimensionIndexes': [0, 0, 24, 31],
#    'inlineDimensions': [],
#    'stringValue': 'lymphoma'},
#   {'dimensionIndexes': [0, 0, 0, 31],
#    'inlineDimensions': [],
#    'numericValue': 2.42},
#   {'dimensionIndexes': [0, 0, 1, 31],
#    'inlineDimensions': [],
#    'numericValue': 80.0},
#   {'dimensionIndexes': [0, 0, 2, 32],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 32],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 9, 32],
#    'inlineDimensions': [],
#    'stringValue': 'male'},
#   {'dimensionIndexes': [0, 0, 5, 32],
#    'inlineDimensions': [],
#    'numericValue': 73.0},
#   {'dimensionIndexes': [0, 0, 6, 32],
#    'inlineDimensions': [],
#    'numericValue': 68.0},
#   {'dimensionIndexes': [0, 0, 11, 32],
#    'inlineDimensions': [],
#    'stringValue': 'not specified'},
#   {'dimensionIndexes': [0, 0, 8, 32],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell adenocarcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 32],
#    'inlineDimensions': [],
#    'numericValue': 2.43},
#   {'dimensionIndexes': [0, 0, 1, 32],
#    'inlineDimensions': [],
#    'numericValue': 69.0},
#   {'dimensionIndexes': [0, 0, 2, 33],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 33],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 4, 33],
#    'inlineDimensions': [],
#    'stringValue': 'female'},
#   {'dimensionIndexes': [0, 0, 5, 33],
#    'inlineDimensions': [],
#    'numericValue': 71.0},
#   {'dimensionIndexes': [0, 0, 6, 33],
#    'inlineDimensions': [],
#    'numericValue': 71.0},
#   {'dimensionIndexes': [0, 0, 11, 33],
#    'inlineDimensions': [],
#    'stringValue': 'not specified'},
#   {'dimensionIndexes': [0, 0, 8, 33],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell adenocarcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 33],
#    'inlineDimensions': [],
#    'numericValue': 1.7},
#   {'dimensionIndexes': [0, 0, 1, 33],
#    'inlineDimensions': [],
#    'numericValue': 72.0},
#   {'dimensionIndexes': [0, 0, 2, 34],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 34],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 9, 34],
#    'inlineDimensions': [],
#    'stringValue': 'male'},
#   {'dimensionIndexes': [0, 0, 5, 34],
#    'inlineDimensions': [],
#    'numericValue': 39.0},
#   {'dimensionIndexes': [0, 0, 6, 34],
#    'inlineDimensions': [],
#    'numericValue': 73.0},
#   {'dimensionIndexes': [0, 0, 11, 34],
#    'inlineDimensions': [],
#    'stringValue': 'not specified'},
#   {'dimensionIndexes': [0, 0, 8, 34],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell adenocarcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 34],
#    'inlineDimensions': [],
#    'numericValue': 2.73},
#   {'dimensionIndexes': [0, 0, 1, 34],
#    'inlineDimensions': [],
#    'numericValue': 80.0},
#   {'dimensionIndexes': [0, 0, 2, 35],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 35],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 9, 35],
#    'inlineDimensions': [],
#    'stringValue': 'male'},
#   {'dimensionIndexes': [0, 0, 5, 35],
#    'inlineDimensions': [],
#    'numericValue': 70.0},
#   {'dimensionIndexes': [0, 0, 6, 35],
#    'inlineDimensions': [],
#    'numericValue': 69.0},
#   {'dimensionIndexes': [0, 0, 11, 35],
#    'inlineDimensions': [],
#    'stringValue': 'not specified'},
#   {'dimensionIndexes': [0, 0, 8, 35],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell adenocarcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 35],
#    'inlineDimensions': [],
#    'numericValue': 2.56},
#   {'dimensionIndexes': [0, 0, 1, 35],
#    'inlineDimensions': [],
#    'numericValue': 61.0},
#   {'dimensionIndexes': [0, 0, 2, 36],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 36],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 9, 36],
#    'inlineDimensions': [],
#    'stringValue': 'male'},
#   {'dimensionIndexes': [0, 0, 5, 36],
#    'inlineDimensions': [],
#    'numericValue': 82.0},
#   {'dimensionIndexes': [0, 0, 6, 36],
#    'inlineDimensions': [],
#    'numericValue': 68.0},
#   {'dimensionIndexes': [0, 0, 11, 36],
#    'inlineDimensions': [],
#    'stringValue': 'not specified'},
#   {'dimensionIndexes': [0, 0, 8, 36],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell adenocarcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 36],
#    'inlineDimensions': [],
#    'numericValue': 2.34},
#   {'dimensionIndexes': [0, 0, 1, 36],
#    'inlineDimensions': [],
#    'numericValue': 81.0},
#   {'dimensionIndexes': [0, 0, 2, 37],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 37],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 9, 37],
#    'inlineDimensions': [],
#    'stringValue': 'male'},
#   {'dimensionIndexes': [0, 0, 5, 37],
#    'inlineDimensions': [],
#    'numericValue': 64.0},
#   {'dimensionIndexes': [0, 0, 6, 37],
#    'inlineDimensions': [],
#    'numericValue': 66.0},
#   {'dimensionIndexes': [0, 0, 11, 37],
#    'inlineDimensions': [],
#    'stringValue': 'not specified'},
#   {'dimensionIndexes': [0, 0, 8, 37],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell adenocarcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 37],
#    'inlineDimensions': [],
#    'numericValue': 2.26},
#   {'dimensionIndexes': [0, 0, 1, 37],
#    'inlineDimensions': [],
#    'numericValue': 83.0},
#   {'dimensionIndexes': [0, 0, 2, 38],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 38],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 9, 38],
#    'inlineDimensions': [],
#    'stringValue': 'male'},
#   {'dimensionIndexes': [0, 0, 5, 38],
#    'inlineDimensions': [],
#    'numericValue': 77.0},
#   {'dimensionIndexes': [0, 0, 6, 38],
#    'inlineDimensions': [],
#    'numericValue': 66.0},
#   {'dimensionIndexes': [0, 0, 11, 38],
#    'inlineDimensions': [],
#    'stringValue': 'not specified'},
#   {'dimensionIndexes': [0, 0, 21, 38],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell squamous cell carcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 38],
#    'inlineDimensions': [],
#    'numericValue': 2.25},
#   {'dimensionIndexes': [0, 0, 4, 39],
#    'inlineDimensions': [],
#    'stringValue': 'female'},
#   {'dimensionIndexes': [0, 0, 1, 38],
#    'inlineDimensions': [],
#    'numericValue': 72.0},
#   {'dimensionIndexes': [0, 0, 2, 39],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 39],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 5, 39],
#    'inlineDimensions': [],
#    'numericValue': 61.0},
#   {'dimensionIndexes': [0, 0, 6, 39],
#    'inlineDimensions': [],
#    'numericValue': 65.0},
#   {'dimensionIndexes': [0, 0, 11, 39],
#    'inlineDimensions': [],
#    'stringValue': 'not specified'},
#   {'dimensionIndexes': [0, 0, 8, 39],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell adenocarcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 39],
#    'inlineDimensions': [],
#    'numericValue': 1.28},
#   {'dimensionIndexes': [0, 0, 1, 39],
#    'inlineDimensions': [],
#    'numericValue': 89.0},
#   {'dimensionIndexes': [0, 0, 5, 40],
#    'inlineDimensions': [],
#    'numericValue': 67.0},
#   {'dimensionIndexes': [0, 0, 2, 40],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 40],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 4, 40],
#    'inlineDimensions': [],
#    'stringValue': 'female'},
#   {'dimensionIndexes': [0, 0, 6, 40],
#    'inlineDimensions': [],
#    'numericValue': 66.0},
#   {'dimensionIndexes': [0, 0, 11, 40],
#    'inlineDimensions': [],
#    'stringValue': 'not specified'},
#   {'dimensionIndexes': [0, 0, 25, 40],
#    'inlineDimensions': [],
#    'stringValue': 'Unknown'},
#   {'dimensionIndexes': [0, 0, 0, 40],
#    'inlineDimensions': [],
#    'numericValue': 1.63},
#   {'dimensionIndexes': [0, 0, 1, 40],
#    'inlineDimensions': [],
#    'numericValue': 80.78},
#   {'dimensionIndexes': [0, 0, 2, 41],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 41],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 4, 41],
#    'inlineDimensions': [],
#    'stringValue': 'female'},
#   {'dimensionIndexes': [0, 0, 5, 41],
#    'inlineDimensions': [],
#    'numericValue': 77.0},
#   {'dimensionIndexes': [0, 0, 6, 41],
#    'inlineDimensions': [],
#    'numericValue': 67.0},
#   {'dimensionIndexes': [0, 0, 17, 41],
#    'inlineDimensions': [],
#    'stringValue': 'chronic obstructive pulmonary disease'},
#   {'dimensionIndexes': [0, 0, 21, 41],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell squamous cell carcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 41],
#    'inlineDimensions': [],
#    'numericValue': 1.29},
#   {'dimensionIndexes': [0, 0, 1, 41],
#    'inlineDimensions': [],
#    'numericValue': 53.0},
#   {'dimensionIndexes': [0, 0, 2, 42],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 42],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 9, 42],
#    'inlineDimensions': [],
#    'stringValue': 'male'},
#   {'dimensionIndexes': [0, 0, 5, 42],
#    'inlineDimensions': [],
#    'numericValue': 64.0},
#   {'dimensionIndexes': [0, 0, 6, 42],
#    'inlineDimensions': [],
#    'numericValue': 65.0},
#   {'dimensionIndexes': [0, 0, 17, 42],
#    'inlineDimensions': [],
#    'stringValue': 'chronic obstructive pulmonary disease'},
#   {'dimensionIndexes': [0, 0, 21, 42],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell squamous cell carcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 42],
#    'inlineDimensions': [],
#    'numericValue': 2.06},
#   {'dimensionIndexes': [0, 0, 1, 42],
#    'inlineDimensions': [],
#    'numericValue': 54.0},
#   {'dimensionIndexes': [0, 0, 2, 43],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 43],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 4, 43],
#    'inlineDimensions': [],
#    'stringValue': 'female'},
#   {'dimensionIndexes': [0, 0, 5, 43],
#    'inlineDimensions': [],
#    'numericValue': 59.0},
#   {'dimensionIndexes': [0, 0, 6, 43],
#    'inlineDimensions': [],
#    'numericValue': 58.0},
#   {'dimensionIndexes': [0, 0, 17, 43],
#    'inlineDimensions': [],
#    'stringValue': 'chronic obstructive pulmonary disease'},
#   {'dimensionIndexes': [0, 0, 21, 43],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell squamous cell carcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 43],
#    'inlineDimensions': [],
#    'numericValue': 0.55},
#   {'dimensionIndexes': [0, 0, 1, 43],
#    'inlineDimensions': [],
#    'numericValue': 44.0},
#   {'dimensionIndexes': [0, 0, 2, 44],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 44],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 9, 44],
#    'inlineDimensions': [],
#    'stringValue': 'male'},
#   {'dimensionIndexes': [0, 0, 5, 44],
#    'inlineDimensions': [],
#    'numericValue': 61.0},
#   {'dimensionIndexes': [0, 0, 6, 44],
#    'inlineDimensions': [],
#    'numericValue': 66.0},
#   {'dimensionIndexes': [0, 0, 17, 44],
#    'inlineDimensions': [],
#    'stringValue': 'chronic obstructive pulmonary disease'},
#   {'dimensionIndexes': [0, 0, 21, 44],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell squamous cell carcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 44],
#    'inlineDimensions': [],
#    'numericValue': 1.7},
#   {'dimensionIndexes': [0, 0, 1, 44],
#    'inlineDimensions': [],
#    'numericValue': 59.0},
#   {'dimensionIndexes': [0, 0, 2, 45],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 45],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 9, 45],
#    'inlineDimensions': [],
#    'stringValue': 'male'},
#   {'dimensionIndexes': [0, 0, 5, 45],
#    'inlineDimensions': [],
#    'numericValue': 63.0},
#   {'dimensionIndexes': [0, 0, 6, 45],
#    'inlineDimensions': [],
#    'numericValue': 72.0},
#   {'dimensionIndexes': [0, 0, 17, 45],
#    'inlineDimensions': [],
#    'stringValue': 'chronic obstructive pulmonary disease'},
#   {'dimensionIndexes': [0, 0, 21, 45],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell squamous cell carcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 45],
#    'inlineDimensions': [],
#    'numericValue': 2.54},
#   {'dimensionIndexes': [0, 0, 1, 45],
#    'inlineDimensions': [],
#    'numericValue': 58.0},
#   {'dimensionIndexes': [0, 0, 2, 46],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 46],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 9, 46],
#    'inlineDimensions': [],
#    'stringValue': 'male'},
#   {'dimensionIndexes': [0, 0, 5, 46],
#    'inlineDimensions': [],
#    'numericValue': 56.0},
#   {'dimensionIndexes': [0, 0, 6, 46],
#    'inlineDimensions': [],
#    'numericValue': 72.0},
#   {'dimensionIndexes': [0, 0, 17, 46],
#    'inlineDimensions': [],
#    'stringValue': 'chronic obstructive pulmonary disease'},
#   {'dimensionIndexes': [0, 0, 21, 46],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell squamous cell carcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 46],
#    'inlineDimensions': [],
#    'numericValue': 1.87},
#   {'dimensionIndexes': [0, 0, 1, 46],
#    'inlineDimensions': [],
#    'numericValue': 56.0},
#   {'dimensionIndexes': [0, 0, 2, 47],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 47],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 9, 47],
#    'inlineDimensions': [],
#    'stringValue': 'male'},
#   {'dimensionIndexes': [0, 0, 5, 47],
#    'inlineDimensions': [],
#    'numericValue': 70.0},
#   {'dimensionIndexes': [0, 0, 6, 47],
#    'inlineDimensions': [],
#    'numericValue': 71.0},
#   {'dimensionIndexes': [0, 0, 17, 47],
#    'inlineDimensions': [],
#    'stringValue': 'chronic obstructive pulmonary disease'},
#   {'dimensionIndexes': [0, 0, 21, 47],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell squamous cell carcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 47],
#    'inlineDimensions': [],
#    'numericValue': 0.9},
#   {'dimensionIndexes': [0, 0, 1, 47],
#    'inlineDimensions': [],
#    'numericValue': 55.9},
#   {'dimensionIndexes': [0, 0, 2, 48],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 10, 48],
#    'inlineDimensions': [],
#    'stringValue': 'Afro American'},
#   {'dimensionIndexes': [0, 0, 4, 48],
#    'inlineDimensions': [],
#    'stringValue': 'female'},
#   {'dimensionIndexes': [0, 0, 5, 48],
#    'inlineDimensions': [],
#    'numericValue': 79.0},
#   {'dimensionIndexes': [0, 0, 6, 48],
#    'inlineDimensions': [],
#    'numericValue': 63.0},
#   {'dimensionIndexes': [0, 0, 17, 48],
#    'inlineDimensions': [],
#    'stringValue': 'chronic obstructive pulmonary disease'},
#   {'dimensionIndexes': [0, 0, 21, 48],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell squamous cell carcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 48],
#    'inlineDimensions': [],
#    'numericValue': 1.3},
#   {'dimensionIndexes': [0, 0, 1, 48],
#    'inlineDimensions': [],
#    'numericValue': 78.0},
#   {'dimensionIndexes': [0, 0, 2, 49],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 49],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 9, 49],
#    'inlineDimensions': [],
#    'stringValue': 'male'},
#   {'dimensionIndexes': [0, 0, 21, 49],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell squamous cell carcinoma'},
#   {'dimensionIndexes': [0, 0, 5, 49],
#    'inlineDimensions': [],
#    'numericValue': 67.0},
#   {'dimensionIndexes': [0, 0, 6, 49],
#    'inlineDimensions': [],
#    'numericValue': 71.0},
#   {'dimensionIndexes': [0, 0, 7, 49],
#    'inlineDimensions': [],
#    'stringValue': 'control'},
#   {'dimensionIndexes': [0, 0, 0, 49],
#    'inlineDimensions': [],
#    'numericValue': 3.11},
#   {'dimensionIndexes': [0, 0, 1, 49],
#    'inlineDimensions': [],
#    'numericValue': 73.0},
#   {'dimensionIndexes': [0, 0, 2, 50],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 50],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 9, 50],
#    'inlineDimensions': [],
#    'stringValue': 'male'},
#   {'dimensionIndexes': [0, 0, 5, 50],
#    'inlineDimensions': [],
#    'numericValue': 69.0},
#   {'dimensionIndexes': [0, 0, 6, 50],
#    'inlineDimensions': [],
#    'numericValue': 67.0},
#   {'dimensionIndexes': [0, 0, 11, 50],
#    'inlineDimensions': [],
#    'stringValue': 'not specified'},
#   {'dimensionIndexes': [0, 0, 21, 50],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell squamous cell carcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 50],
#    'inlineDimensions': [],
#    'numericValue': 2.13},
#   {'dimensionIndexes': [0, 0, 1, 50],
#    'inlineDimensions': [],
#    'numericValue': 71.0},
#   {'dimensionIndexes': [0, 0, 2, 51],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 51],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 9, 51],
#    'inlineDimensions': [],
#    'stringValue': 'male'},
#   {'dimensionIndexes': [0, 0, 5, 51],
#    'inlineDimensions': [],
#    'numericValue': 74.0},
#   {'dimensionIndexes': [0, 0, 6, 51],
#    'inlineDimensions': [],
#    'numericValue': 70.0},
#   {'dimensionIndexes': [0, 0, 11, 51],
#    'inlineDimensions': [],
#    'stringValue': 'not specified'},
#   {'dimensionIndexes': [0, 0, 21, 51],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell squamous cell carcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 51],
#    'inlineDimensions': [],
#    'numericValue': 2.61},
#   {'dimensionIndexes': [0, 0, 1, 51],
#    'inlineDimensions': [],
#    'numericValue': 70.0},
#   {'dimensionIndexes': [0, 0, 2, 52],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 52],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 4, 52],
#    'inlineDimensions': [],
#    'stringValue': 'female'},
#   {'dimensionIndexes': [0, 0, 5, 52],
#    'inlineDimensions': [],
#    'numericValue': 56.0},
#   {'dimensionIndexes': [0, 0, 6, 52],
#    'inlineDimensions': [],
#    'numericValue': 60.0},
#   {'dimensionIndexes': [0, 0, 17, 52],
#    'inlineDimensions': [],
#    'stringValue': 'chronic obstructive pulmonary disease'},
#   {'dimensionIndexes': [0, 0, 21, 52],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell squamous cell carcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 52],
#    'inlineDimensions': [],
#    'numericValue': 0.52},
#   {'dimensionIndexes': [0, 0, 1, 52],
#    'inlineDimensions': [],
#    'numericValue': 58.0},
#   {'dimensionIndexes': [0, 0, 2, 53],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 53],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 4, 53],
#    'inlineDimensions': [],
#    'stringValue': 'female'},
#   {'dimensionIndexes': [0, 0, 5, 53],
#    'inlineDimensions': [],
#    'numericValue': 53.0},
#   {'dimensionIndexes': [0, 0, 6, 53],
#    'inlineDimensions': [],
#    'numericValue': 64.0},
#   {'dimensionIndexes': [0, 0, 7, 53],
#    'inlineDimensions': [],
#    'stringValue': 'control'},
#   {'dimensionIndexes': [0, 0, 21, 53],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell squamous cell carcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 53],
#    'inlineDimensions': [],
#    'numericValue': 2.72},
#   {'dimensionIndexes': [0, 0, 1, 53],
#    'inlineDimensions': [],
#    'numericValue': 74.0},
#   {'dimensionIndexes': [0, 0, 2, 54],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 54],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 9, 54],
#    'inlineDimensions': [],
#    'stringValue': 'male'},
#   {'dimensionIndexes': [0, 0, 5, 54],
#    'inlineDimensions': [],
#    'numericValue': 71.0},
#   {'dimensionIndexes': [0, 0, 6, 54],
#    'inlineDimensions': [],
#    'numericValue': 71.0},
#   {'dimensionIndexes': [0, 0, 7, 54],
#    'inlineDimensions': [],
#    'stringValue': 'control'},
#   {'dimensionIndexes': [0, 0, 8, 54],
#    'inlineDimensions': [],
#    'stringValue': 'non-small cell adenocarcinoma'},
#   {'dimensionIndexes': [0, 0, 0, 54],
#    'inlineDimensions': [],
#    'numericValue': 3.66},
#   {'dimensionIndexes': [0, 0, 1, 54],
#    'inlineDimensions': [],
#    'numericValue': 72.0},
#   {'dimensionIndexes': [0, 0, 2, 55],
#    'inlineDimensions': [],
#    'stringValue': 'Homo sapiens'},
#   {'dimensionIndexes': [0, 0, 3, 55],
#    'inlineDimensions': [],
#    'stringValue': 'Caucasian'},
#   {'dimensionIndexes': [0, 0, 4, 55],
#    'inlineDimensions': [],
#    'stringValue': 'female'},
#   {'dimensionIndexes': [0, 0, 5, 55],
#    'inlineDimensions': [],
#    'numericValue': 57.0},
#   {'dimensionIndexes': [0, 0, 6, 55],
#    'inlineDimensions': [],
#    'numericValue': 65.0},
#   {'dimensionIndexes': [0, 0, 7, 55],
#    'inlineDimensions': [],
#    'stringValue': 'control'},
#   {'dimensionIndexes': [0, 0, 8, 55],
#    'inlineDimensions': [],
# ...
#    {'conceptCode': '1341301',
#     'conceptPath': '\\Public Studies\\GSE8581\\Endpoints\\Diagnosis\\giant bullae\\'},
#    {'conceptCode': '1341314',
#     'conceptPath': '\\Public Studies\\GSE8581\\Endpoints\\Diagnosis\\emphysema\\'},
#    {'conceptCode': '1341299',
#     'conceptPath': '\\Public Studies\\GSE8581\\Endpoints\\Diagnosis\\carcinoid\\'},
#    {'conceptCode': '1341297',
#     'conceptPath': '\\Public Studies\\GSE8581\\Endpoints\\Diagnosis\\non-small cell squamous cell carcinoma\\'},
#    {'conceptCode': '1341317',
#     'conceptPath': '\\Public Studies\\GSE8581\\Endpoints\\Diagnosis\\Giant Cell Tumor\\'},
#    {'conceptCode': '1341275',
#     'conceptPath': '\\Public Studies\\GSE8581\\Endpoints\\Diagnosis\\NSC-Mixed\\'},
#    {'conceptCode': '1341277',
#     'conceptPath': '\\Public Studies\\GSE8581\\Endpoints\\Diagnosis\\lymphoma\\'},
#    {'conceptCode': '1341340',
#     'conceptPath': '\\Public Studies\\GSE8581\\Endpoints\\Diagnosis\\Unknown\\'},
#    {'conceptCode': '1341363',
#     'conceptPath': '\\Public Studies\\GSE8581\\Biomarker Data\\GPL570_BOGUS\\Lung\\'}],
#   'patient': [{'age': 65,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384788,
#     'inTrialId': 'GSE8581GSM210006',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 50,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384787,
#     'inTrialId': 'GSE8581GSM210192',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 68,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384816,
#     'inTrialId': 'GSE8581GSM210087',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 55,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384815,
#     'inTrialId': 'GSE8581GSM210979',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 68,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384814,
#     'inTrialId': 'GSE8581GSM210015',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'male',
#     'sexCd': 'male',
#     'trial': 'GSE8581'},
#    {'age': 71,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384813,
#     'inTrialId': 'GSE8581GSM210014',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 84,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384812,
#     'inTrialId': 'GSE8581GSM210005',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 61,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384811,
#     'inTrialId': 'GSE8581GSM211010',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 61,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384810,
#     'inTrialId': 'GSE8581GSM210012',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'male',
#     'sexCd': 'male',
#     'trial': 'GSE8581'},
#    {'age': 79,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384809,
#     'inTrialId': 'GSE8581GSM213017',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'male',
#     'sexCd': 'male',
#     'trial': 'GSE8581'},
#    {'age': 73,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384808,
#     'inTrialId': 'GSE8581GSM210978',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 77,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384807,
#     'inTrialId': 'GSE8581GSM210010',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 46,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384836,
#     'inTrialId': 'GSE8581GSM210007',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'male',
#     'sexCd': 'male',
#     'trial': 'GSE8581'},
#    {'age': 81,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384835,
#     'inTrialId': 'GSE8581GSM212069',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 78,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384834,
#     'inTrialId': 'GSE8581GSM212068',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 65,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384833,
#     'inTrialId': 'GSE8581GSM210188',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 55,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384832,
#     'inTrialId': 'GSE8581GSM212067',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'male',
#     'sexCd': 'male',
#     'trial': 'GSE8581'},
#    {'age': 50,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384831,
#     'inTrialId': 'GSE8581GSM210090',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'male',
#     'sexCd': 'male',
#     'trial': 'GSE8581'},
#    {'age': 61,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384830,
#     'inTrialId': 'GSE8581GSM210993',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'male',
#     'sexCd': 'male',
#     'trial': 'GSE8581'},
#    {'age': 68,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384829,
#     'inTrialId': 'GSE8581GSM210071',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'male',
#     'sexCd': 'male',
#     'trial': 'GSE8581'},
#    {'age': 40,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384828,
#     'inTrialId': 'GSE8581GSM212070',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'male',
#     'sexCd': 'male',
#     'trial': 'GSE8581'},
#    {'age': 71,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384827,
#     'inTrialId': 'GSE8581GSM212850',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'male',
#     'sexCd': 'male',
#     'trial': 'GSE8581'},
#    {'age': 64,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384856,
#     'inTrialId': 'GSE8581GSM210994',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 75,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384855,
#     'inTrialId': 'GSE8581GSM213020',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'male',
#     'sexCd': 'male',
#     'trial': 'GSE8581'},
#    {'age': 52,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384854,
#     'inTrialId': 'GSE8581GSM212810',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 72,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384853,
#     'inTrialId': 'GSE8581GSM212852',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 54,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384852,
#     'inTrialId': 'GSE8581GSM212790',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 78,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384851,
#     'inTrialId': 'GSE8581GSM212787',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'male',
#     'sexCd': 'male',
#     'trial': 'GSE8581'},
#    {'age': 62,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384850,
#     'inTrialId': 'GSE8581GSM212789',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 59,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384849,
#     'inTrialId': 'GSE8581GSM213036',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 77,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384848,
#     'inTrialId': 'GSE8581GSM212811',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 71,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384847,
#     'inTrialId': 'GSE8581GSM212853',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 73,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384876,
#     'inTrialId': 'GSE8581GSM212855',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'male',
#     'sexCd': 'male',
#     'trial': 'GSE8581'},
#    {'age': 71,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384875,
#     'inTrialId': 'GSE8581GSM213019',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 39,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384874,
#     'inTrialId': 'GSE8581GSM212849',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'male',
#     'sexCd': 'male',
#     'trial': 'GSE8581'},
#    {'age': 70,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384873,
#     'inTrialId': 'GSE8581GSM213034',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'male',
#     'sexCd': 'male',
#     'trial': 'GSE8581'},
#    {'age': 82,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384872,
#     'inTrialId': 'GSE8581GSM213018',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'male',
#     'sexCd': 'male',
#     'trial': 'GSE8581'},
#    {'age': 64,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384871,
#     'inTrialId': 'GSE8581GSM212854',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'male',
#     'sexCd': 'male',
#     'trial': 'GSE8581'},
#    {'age': 77,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384870,
#     'inTrialId': 'GSE8581GSM213037',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'male',
#     'sexCd': 'male',
#     'trial': 'GSE8581'},
#    {'age': 61,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384869,
#     'inTrialId': 'GSE8581GSM212809',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 67,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384776,
#     'inTrialId': 'GSE8581GSM210193',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 77,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384775,
#     'inTrialId': 'GSE8581GSM212788',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 64,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384774,
#     'inTrialId': 'GSE8581GSM212074',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'male',
#     'sexCd': 'male',
#     'trial': 'GSE8581'},
#    {'age': 59,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384773,
#     'inTrialId': 'GSE8581GSM212848',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 61,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384772,
#     'inTrialId': 'GSE8581GSM211007',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'male',
#     'sexCd': 'male',
#     'trial': 'GSE8581'},
#    {'age': 63,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384771,
#     'inTrialId': 'GSE8581GSM210004',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'male',
#     'sexCd': 'male',
#     'trial': 'GSE8581'},
#    {'age': 56,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384770,
#     'inTrialId': 'GSE8581GSM210011',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'male',
#     'sexCd': 'male',
#     'trial': 'GSE8581'},
#    {'age': 70,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384769,
#     'inTrialId': 'GSE8581GSM210992',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'male',
#     'sexCd': 'male',
#     'trial': 'GSE8581'},
#    {'age': 79,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384768,
#     'inTrialId': 'GSE8581GSM212075',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 67,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384767,
#     'inTrialId': 'GSE8581GSM213035',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'male',
#     'sexCd': 'male',
#     'trial': 'GSE8581'},
#    {'age': 69,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384796,
#     'inTrialId': 'GSE8581GSM211865',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'male',
#     'sexCd': 'male',
#     'trial': 'GSE8581'},
#    {'age': 74,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384795,
#     'inTrialId': 'GSE8581GSM211872',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'male',
#     'sexCd': 'male',
#     'trial': 'GSE8581'},
#    {'age': 56,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384794,
#     'inTrialId': 'GSE8581GSM210194',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 53,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384793,
#     'inTrialId': 'GSE8581GSM210009',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 71,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384792,
#     'inTrialId': 'GSE8581GSM211008',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'male',
#     'sexCd': 'male',
#     'trial': 'GSE8581'},
#    {'age': 57,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384791,
#     'inTrialId': 'GSE8581GSM210196',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 53,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384790,
#     'inTrialId': 'GSE8581GSM210008',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'female',
#     'sexCd': 'female',
#     'trial': 'GSE8581'},
#    {'age': 75,
#     'birthDate': None,
#     'deathDate': None,
#     'id': 1000384789,
#     'inTrialId': 'GSE8581GSM211009',
#     'maritalStatus': None,
#     'race': None,
#     'religion': None,
#     'sex': 'male',
#     'sexCd': 'male',
#     'trial': 'GSE8581'}],
#   'study': [{'name': 'GSE8581'}],
#   'trial visit': [{'id': 122,
#     'relTime': None,
#     'relTimeLabel': 'General',
#     'relTimeUnit': None}]}}
